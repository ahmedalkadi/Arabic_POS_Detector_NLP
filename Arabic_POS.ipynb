# %% [markdown]
# **Instruction for POS Tagging with Arabic Dataset**
#
# **Dataset:**
# The dataset provided is named "Arabic POS.conllu". It contains labeled data for Arabic text with Part-of-Speech (POS) tags in CoNLL-U format.
#
# **Objective:**
# Your objective is to perform Part-of-Speech (POS) tagging on Arabic text using Recurrent Neural Networks (RNNs). Specifically, you will use the Universal POS (UPOS) tags for tagging. UPOS is a standardized set of POS tags that aims to cover all languages.
#
# **Instructions:**
# 1. **Data Preprocessing:**
#    - Load the provided dataset "Arabic POS.conllu".
#    - Preprocess the data as necessary, including tokenization
#
# 2. **Model Building:**
#    - Design an architecture suitable for POS tagging.I have used recurrent layers such as (LSTM) or (GRU).
#    - Define the input and output layers of the model. The input layer should accept sequences of tokens, and the output layer should produce the predicted UPOS tags for each token.
#
# 3. **Training:**
#
# 4. **Evaluation:**

# %%
# !pip install pyconll
# Out:
# Collecting pyconll
#   Downloading pyconll-3.2.0-py3-none-any.whl (27 kB)
# Installing collected packages: pyconll
# Successfully installed pyconll-3.2.0

# %% [markdown]
# ### Import used libraries

# %%
import pyconll
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
from keras.optimizers import Adam
from keras.models import load_model

# %% [markdown]
# ### Load Dataset

# %%
data = pyconll.load_from_file("Arabic POS.conllu")

# %% [markdown]
# ### Data splitting

# %%
sentences = []
pos_tags = []

# create a list of words in a list of sentences
for sentence in data:
    sent = [token.form for token in sentence]
    pos = [token.upos for token in sentence]

    sentences.append(sent)
    pos_tags.append(pos)

# %%
# the number of sentenses in the file
print("the number of the sentences is :",len(sentences))
# Out:
# the number of the sentences is : 6075

# %%
# split the data into train and test data sets



train_sentences, test_sentences, train_pos, test_pos = train_test_split(sentences, pos_tags, test_size=0.2, random_state=42)
# train_sentences, val_sentences, train_pos, val_pos = train_test_split(train_sentences, train_pos, test_size=0.1, random_state=42)

# Check sizes of split sets

print("Train set size:", len(train_sentences))
# print("Validation set size:", len(val_sentences))
print("Test set size:", len(test_sentences))
# Out:
# Train set size: 4860
# Test set size: 1215

# %% [markdown]
# ### Cleaning and Preprocessing

# %%
for i in sentences[0]:
    print(i ,end=" ")

print()

a=[i if i !="X" else "null" for i in pos_tags[0]]
for i in range(len(a)):
    print(a[-(i+1)],end=" ")
# Out:
# برلين ترفض حصول شركة اميركية على رخصة تصنيع دبابة " ليوبارد " الالمانية
# ADJ PUNCT null PUNCT NOUN NOUN NOUN ADP ADJ NOUN NOUN VERB null

# %%
# create a function to read the sentences in lines with its POS

def read_sentences(sentences,pos_tags,show_pos=True,num=7):

    for j in range(num):
        for i in sentences[j]:
            print(i ,end=" ")

        if show_pos:
            print()
            a=[i if i !="X" else "null" for i in pos_tags[j]]
            for i in range(len(a)):
                print(a[-(i+1)],end=" ")
            print("\n")
        else:
            print("\n")

# %%
# show some sentences

read_sentences(sentences,pos_tags)
# Out:
# برلين ترفض حصول شركة اميركية على رخصة تصنيع دبابة " ليوبارد " الالمانية
# ADJ PUNCT null PUNCT NOUN NOUN NOUN ADP ADJ NOUN NOUN VERB null
#
# برلين 15 - 7 ( اف ب ) - افادت صحيفة الاحد الالمانية " ويلت ام سونتاغ " في عددها عدد ها الصادر غدا ، ان المستشار غيرهارد شرودر يرفض حصول المجموعة الاميركية " جنرال ديناميكس " على رخصة لتصنيع ل تصنيع الدبابة الالمانية " ليوبارد 2 " عبر شراء المجموعة الحكومية الاسبانية للاسلحة ل الأسلحة " سانتا بربارة " .
# PUNCT PUNCT null null PUNCT NOUN ADP None ADJ ADJ NOUN NOUN ADP PUNCT NUM null PUNCT ADJ NOUN NOUN ADP None NOUN ADP PUNCT null null PUNCT ADJ NOUN NOUN VERB null null NOUN SCONJ PUNCT NOUN ADJ PRON NOUN None ADP PUNCT null null null PUNCT ADJ NOUN NOUN VERB PUNCT PUNCT null null PUNCT NUM PUNCT NUM null
#
# وفي و في نيسان / ابريل الماضي ، تخلت الدولة الاسبانية عن مجموعة " سانتا بربارة " التي تصنع دبابات ليوبارد الالمانية ، الى " جنرال ديناميكس " التي تنتج الدبابة الاميركية " ام 1 ابرامس " المعتبرة المنافسة الرئيسية لدبابة ل دبابة ليوبارد في الاسواق .
# PUNCT NOUN ADP null NOUN ADP None ADJ NOUN ADJ PUNCT null NUM null PUNCT ADJ NOUN VERB null PUNCT null null PUNCT ADP PUNCT ADJ null NOUN VERB DET PUNCT null null PUNCT NOUN ADP ADJ NOUN VERB PUNCT ADJ NOUN PUNCT NOUN ADP CCONJ None
#
# وكانت و كانت خسائر المجموعة الاسبانية الرسمية تراكمت في السنوات العشر الاخيرة لتبلغ ل تبلغ 920 مليون يورو .
# PUNCT NOUN NUM NUM VERB CCONJ None ADJ NUM NOUN ADP VERB ADJ ADJ NOUN NOUN VERB CCONJ None
#
# واشارت و أشارت صحيفة الاحد الى ان المستشار شرودر يعتبر ان حصول المجموعة الاميركية على رخصة تصنيع ليوبارد 2 يعرض للخطر ل الخطر المصالح التكنولوجية الاساسية لالمانيا ل ألمانيا وطلب و طلب من وزير الدفاع رودولف شاربينغ التوجه الى اسبانيا .
# PUNCT null ADP NOUN null null NOUN NOUN ADP VERB CCONJ None null ADP None ADJ ADJ NOUN NOUN ADP None VERB NUM null NOUN NOUN ADP ADJ NOUN NOUN SCONJ VERB null NOUN SCONJ ADP NOUN NOUN VERB CCONJ None
#
# وتعذر و تعذر لمتحدثة ل متحدثة باسم ب اسم وزارة الدفاع الالمانية ان تؤكد اليوم السبت هذه المعلومات .
# PUNCT NOUN DET NOUN NOUN VERB SCONJ ADJ NOUN NOUN NOUN ADP None NOUN ADP None VERB CCONJ None
#
# وفي و في 21 حزيران / يونيو ، شدد وزير الدفاع الاسباني فيديريكو تريو على ان العقد الموقع في نهاية عام 1998 بين سانتا بربارة ومنتجي و منتجي الدبابة الالمانية ، كروس ك روس مافييه ورينمينتال لتصنيع ل تصنيع الدبابة في اسبانيا وانتاج و إنتاج 235 دبابة ليوبارد 2 خلال عشر سنوات ، يتضمن بندا لحماية ل حماية التكنولوجيا الالمانية ويجب و يجب في " جميع الاحوال " ان تحترمه تحترم ه شركة " جنرال ديناميكس " الاميركية .
# PUNCT ADJ PUNCT null null PUNCT NOUN PRON VERB None SCONJ PUNCT NOUN NOUN PUNCT ADP VERB CCONJ None ADJ NOUN NOUN ADP None NOUN VERB PUNCT NOUN NUM ADP NUM null NOUN NUM NOUN CCONJ None null ADP NOUN NOUN ADP None null null null ADP None PUNCT ADJ NOUN NOUN CCONJ None null null ADP NUM NOUN NOUN ADP ADJ NOUN SCONJ ADP null null ADJ NOUN NOUN VERB PUNCT NOUN PUNCT NOUN NUM ADP CCONJ None

# %%
sen_num=2
for i in range(len(sentences[sen_num])):
    print(sentences[sen_num][i],"==>",pos_tags[sen_num][i])
# Out:
# وفي ==> None
# و ==> CCONJ
# في ==> ADP
# نيسان ==> NOUN
# / ==> PUNCT
# ابريل ==> NOUN
# الماضي ==> ADJ
# ، ==> PUNCT
# تخلت ==> VERB
# الدولة ==> NOUN
# الاسبانية ==> ADJ
# عن ==> ADP
# مجموعة ==> NOUN
# " ==> PUNCT
# سانتا ==> X
# بربارة ==> X
# " ==> PUNCT
# التي ==> DET
# تصنع ==> VERB
# دبابات ==> NOUN
# ليوبارد ==> X
# الالمانية ==> ADJ
# ، ==> PUNCT
# الى ==> ADP
# " ==> PUNCT
# جنرال ==> X
# ديناميكس ==> X
# " ==> PUNCT
# التي ==> X
# تنتج ==> VERB
# الدبابة ==> NOUN
# الاميركية ==> ADJ
# " ==> PUNCT
# ام ==> X
# 1 ==> NUM
# ابرامس ==> X
# " ==> PUNCT
# المعتبرة ==> ADJ
# المنافسة ==> NOUN
# الرئيسية ==> ADJ
# لدبابة ==> None
# ل ==> ADP
# دبابة ==> NOUN
# ليوبارد ==> X
# في ==> ADP
# الاسواق ==> NOUN
# . ==> PUNCT

# %%
for i in range(len(sentences)):
    for j in range(len(sentences[i])):
        print(sentences[i][j],"==>",pos_tags[i][j])
# Out:
# Streaming output truncated to the last 5000 lines.
# . ==> PUNCT
# واكد ==> None
# و ==> CCONJ
# أكد ==> VERB
# وزير ==> NOUN
# الدفاع ==> NOUN
# الكونغولى ==> ADJ
# ايرونج ==> X
# اوان ==> X
# ان ==> SCONJ
# الحادث ==> NOUN
# وقع ==> VERB
# ليلة ==> NOUN
# امس ==> ADV
# ، ==> PUNCT
# بيد ==> CCONJ
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# قال ==> VERB
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# لا ==> PART
# يعلم ==> VERB
# عدد ==> NOUN
# الضحايا ==> NOUN
# . ==> PUNCT
# ويعتقد ==> None
# و ==> CCONJ
# يعتقد ==> VERB
# مسئولان ==> NOUN
# بمطار ==> None
# ب ==> ADP
# مطار ==> NOUN
# كينشاسا ==> X
# الدولى ==> ADJ
# ان ==> SCONJ
# حوالى ==> ADP
# 160 ==> NUM
# راكبا ==> NOUN
# ربما ==> PART
# سقطوا ==> VERB
# من ==> ADP
# الطائرة ==> NOUN
# . ==> PUNCT
# شرودر ==> X
# يدافع ==> VERB
# عن ==> ADP
# موقفه ==> None
# موقف ==> NOUN
# ه ==> PRON
# المعارض ==> ADJ
# للحرب ==> None
# ل ==> ADP
# الحرب ==> NOUN
# على ==> ADP
# العراق ==> NOUN
# برلين ==> X
# 9 ==> NUM
# مايو ==> NOUN
# دافع ==> VERB
# المستشار ==> NOUN
# الالمانى ==> ADJ
# جيرهارد ==> X
# شرودر ==> X
# اليوم ==> NOUN
# عن ==> ADP
# موقف ==> NOUN
# حكومته ==> None
# حكومة ==> NOUN
# ه ==> PRON
# المعارض ==> ADJ
# للحرب ==> None
# ل ==> ADP
# الحرب ==> NOUN
# التى ==> DET
# قادتها ==> None
# قادت ==> VERB
# ها ==> PRON
# الولايات ==> NOUN
# المتحدة ==> ADJ
# ضد ==> ADP
# العراق ==> NOUN
# وسياسة ==> None
# و ==> CCONJ
# سياسة ==> NOUN
# الحكومة ==> NOUN
# حول ==> ADP
# اوربا ==> X
# قوية ==> ADJ
# . ==> PUNCT
# وخلال ==> None
# و ==> CCONJ
# خلال ==> ADP
# كلمته ==> None
# كلمة ==> NOUN
# ه ==> PRON
# امام ==> ADP
# غرفة ==> NOUN
# التجارة ==> NOUN
# الامريكية ==> ADJ
# فى ==> ADP
# المانيا ==> X
# ، ==> PUNCT
# قال ==> VERB
# شرودر ==> X
# ان ==> SCONJ
# العلاقات ==> NOUN
# بين ==> ADP
# المانيا ==> X
# والولايات ==> None
# و ==> CCONJ
# الولايات ==> NOUN
# المتحدة ==> ADJ
# " ==> PUNCT
# ذات ==> NOUN
# اهمية ==> X
# حيوية ==> X
# " ==> PUNCT
# ، ==> PUNCT
# بيد ==> CCONJ
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# من ==> ADP
# الممكن ==> ADJ
# حدوث ==> NOUN
# خلافات ==> NOUN
# بين ==> ADP
# الدولتين ==> NOUN
# . ==> PUNCT
# واضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# ان ==> SCONJ
# الذاكرة ==> X
# الجماعية ==> ADJ
# للهزيمة ==> None
# ل ==> ADP
# الهزيمة ==> NOUN
# فى ==> ADP
# الحربين ==> NOUN
# العالميتين ==> ADJ
# الاولى ==> ADJ
# والثانية ==> None
# و ==> CCONJ
# الثانية ==> ADJ
# فى ==> ADP
# القرن ==> NOUN
# الماضى ==> ADJ
# ، ==> PUNCT
# جعلت ==> VERB
# معظم ==> NOUN
# الالمان ==> NOUN
# دعاة ==> X
# سلام ==> NOUN
# ، ==> PUNCT
# وسيظل ==> None
# و ==> CCONJ
# س ==> AUX
# يظل ==> VERB
# الحال ==> NOUN
# هكذا ==> DET
# بالنسبة ==> None
# ب ==> ADP
# النسبة ==> NOUN
# للصراعات ==> None
# ل ==> ADP
# الصراعات ==> NOUN
# المستقبلية ==> ADJ
# . ==> PUNCT
# واكد ==> None
# و ==> CCONJ
# أكد ==> VERB
# ان ==> SCONJ
# المانيا ==> X
# لن ==> PART
# تتخلى ==> VERB
# عن ==> ADP
# مسئولياتها ==> None
# مسؤوليات ==> NOUN
# ها ==> PRON
# العالمية ==> ADJ
# ، ==> PUNCT
# لكن ==> X
# تاريخها ==> None
# تاريخ ==> NOUN
# ها ==> PRON
# وجغرافيتها ==> None
# و ==> CCONJ
# جغرافية ==> NOUN
# ها ==> PRON
# يشيران ==> VERB
# الى ==> ADP
# انها ==> None
# أن ==> SCONJ
# ها ==> PRON
# ستسعى ==> None
# س ==> AUX
# تسعى ==> VERB
# فى ==> ADP
# المقام ==> NOUN
# الاول ==> ADJ
# الى ==> ADP
# دور ==> NOUN
# نشط ==> ADJ
# ينحصر ==> VERB
# فى ==> ADP
# اوربا ==> X
# . ==> PUNCT
# واضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# قائلا ==> ADJ
# ان ==> SCONJ
# اتحادا ==> NOUN
# اوربيا ==> ADJ
# قويا ==> ADJ
# سيخدم ==> None
# س ==> AUX
# يخدم ==> VERB
# مصلحة ==> NOUN
# الولايات ==> NOUN
# المتحدة ==> ADJ
# . ==> PUNCT
# كما ==> CCONJ
# تعهد ==> VERB
# شرودر ==> X
# بمواصلة ==> None
# ب ==> ADP
# مواصلة ==> NOUN
# توثيق ==> NOUN
# العلاقات ==> NOUN
# مع ==> ADP
# باريس ==> X
# ، ==> PUNCT
# قائلا ==> ADJ
# ان ==> SCONJ
# العلاقات ==> NOUN
# مع ==> ADP
# فرنسا ==> X
# والولايات ==> None
# و ==> CCONJ
# الولايات ==> NOUN
# المتحدة ==> ADJ
# ذات ==> NOUN
# اهمية ==> X
# حيوية ==> X
# بالنسبة ==> None
# ب ==> ADP
# النسبة ==> NOUN
# لالمانيا ==> None
# ل ==> ADP
# ألمانيا ==> X
# . ==> PUNCT
# مجلس ==> NOUN
# الشيوخ ==> NOUN
# الامريكى ==> ADJ
# يوافق ==> VERB
# على ==> ADP
# مشروع ==> NOUN
# قانون ==> NOUN
# حول ==> ADP
# التنصت ==> NOUN
# على ==> ADP
# الاجانب ==> NOUN
# واشنطن ==> X
# 9 ==> NUM
# مايو ==> NOUN
# وافق ==> VERB
# مجلس ==> NOUN
# الشيوخ ==> NOUN
# الامريكى ==> ADJ
# على ==> ADP
# مشروع ==> NOUN
# القانون ==> NOUN
# الجديد ==> ADJ
# 90 ==> NUM
# - ==> PUNCT
# 4 ==> NUM
# للتنصت ==> None
# ل ==> ADP
# التنصت ==> NOUN
# على ==> ADP
# الافراد ==> NOUN
# الاجانب ==> ADJ
# الذى ==> DET
# يوسع ==> VERB
# قانون ==> NOUN
# مراقبة ==> NOUN
# المخابرات ==> NOUN
# للاجانب ==> None
# ل ==> ADP
# الأجانب ==> NOUN
# لعام ==> None
# ل ==> ADP
# عام ==> NOUN
# 1978 ==> NUM
# . ==> PUNCT
# قدم ==> VERB
# مشروع ==> NOUN
# القانون ==> NOUN
# عضوا ==> NOUN
# مجلس ==> NOUN
# الشيوخ ==> NOUN
# تشارلز ==> X
# شومر ==> X
# الديمقراطى ==> X
# عن ==> ADP
# نيو ==> X
# يورك ==> X
# وجون ==> None
# و ==> CCONJ
# جون ==> X
# كيل ==> X
# الجمهورى ==> X
# عن ==> ADP
# اريزونا ==> X
# . ==> PUNCT
# وينتظر ==> None
# و ==> CCONJ
# ينتظر ==> VERB
# المشروع ==> NOUN
# موافقة ==> NOUN
# مجلس ==> NOUN
# النواب ==> NOUN
# ايضا ==> ADV
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# شومر ==> X
# عقب ==> ADP
# التصويت ==> NOUN
# الذى ==> DET
# تم ==> VERB
# ليلة ==> NOUN
# امس ==> ADV
# الخميس ==> NOUN
# " ==> PUNCT
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# تشريع ==> NOUN
# معقول ==> ADJ
# يتعامل ==> VERB
# مع ==> ADP
# عالم ==> NOUN
# ما ==> DET
# بعد ==> ADP
# 11 ==> NUM
# سبتمبر ==> NOUN
# . ==> PUNCT
# " ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# " ==> PUNCT
# ان ==> SCONJ
# الافراد ==> X
# المجهزين ==> ADJ
# بالتكنولوجيا ==> None
# ب ==> ADP
# التكنولوجيا ==> NOUN
# يمكن ==> VERB
# ان ==> SCONJ
# يحدثوا ==> VERB
# ايضا ==> ADV
# خسائر ==> NOUN
# فادحة ==> ADJ
# لوطننا ==> None
# ل ==> ADP
# وطن ==> NOUN
# نا ==> PRON
# هنا ==> ADV
# . ==> PUNCT
# " ==> PUNCT
# ويمكن ==> None
# و ==> CCONJ
# يمكن ==> VERB
# القانون ==> NOUN
# الجديد ==> ADJ
# مسؤولى ==> NOUN
# تنفيذ ==> NOUN
# القانون ==> NOUN
# ، ==> PUNCT
# الذين ==> DET
# يحققون ==> VERB
# فى ==> ADP
# قضايا ==> NOUN
# جواسيس ==> NOUN
# او ==> CCONJ
# ارهابيين ==> NOUN
# مشتبه ==> ADJ
# فيهم ==> None
# في ==> ADP
# هم ==> PRON
# ، ==> PUNCT
# من ==> ADP
# التنصت ==> NOUN
# على ==> ADP
# الافراد ==> NOUN
# الاجانب ==> ADJ
# حتى ==> ADV
# لو ==> CCONJ
# لم ==> PART
# يكونوا ==> VERB
# على ==> ADP
# صلة ==> NOUN
# بحكومة ==> None
# ب ==> ADP
# حكومة ==> NOUN
# او ==> CCONJ
# منظمة ==> NOUN
# ارهابية ==> X
# . ==> PUNCT
# ويطلب ==> None
# و ==> CCONJ
# يطلب ==> VERB
# قانون ==> NOUN
# مراقبة ==> NOUN
# المخابرات ==> NOUN
# للاجانب ==> None
# ل ==> ADP
# الأجانب ==> NOUN
# لعام ==> None
# ل ==> ADP
# عام ==> NOUN
# 1978 ==> NUM
# من ==> ADP
# مسؤولى ==> NOUN
# تنفيذ ==> NOUN
# القانون ==> NOUN
# الحصول ==> NOUN
# على ==> ADP
# تصريح ==> NOUN
# من ==> ADP
# محكمة ==> NOUN
# سرية ==> ADJ
# باستخدام ==> None
# ب ==> ADP
# استخدام ==> NOUN
# اجهزة ==> NOUN
# التنصت ==> NOUN
# لجمع ==> None
# ل ==> ADP
# جمع ==> NOUN
# المعلومات ==> NOUN
# الاستخباراتية ==> ADJ
# ، ==> PUNCT
# اذا ==> CCONJ
# استطاعوا ==> VERB
# اثبات ==> X
# ان ==> SCONJ
# المستهدف ==> X
# " ==> PUNCT
# عميل ==> X
# لسلطة ==> None
# ل ==> ADP
# سلطة ==> NOUN
# اجنبية ==> X
# " ==> PUNCT
# او ==> CCONJ
# جماعة ==> NOUN
# اجنبية ==> ADJ
# . ==> PUNCT
# الولايات ==> NOUN
# المتحدة ==> ADJ
# تدعو ==> VERB
# لانشاء ==> None
# ل ==> ADP
# إنشاء ==> NOUN
# منطقة ==> NOUN
# تجارة ==> NOUN
# حرة ==> ADJ
# فى ==> ADP
# الشرق ==> NOUN
# الاوسط ==> ADJ
# واشنطن ==> X
# 9 ==> NUM
# مايو ==> NOUN
# ذكرت ==> VERB
# صحيفة ==> NOUN
# واشنطن ==> X
# تايمز ==> X
# اليوم ==> NOUN
# ان ==> SCONJ
# الولايات ==> NOUN
# المتحدة ==> ADJ
# ستدعو ==> None
# س ==> AUX
# تدعو ==> VERB
# لانشاء ==> None
# ل ==> ADP
# إنشاء ==> NOUN
# منطقة ==> NOUN
# تجارة ==> NOUN
# حرة ==> ADJ
# فى ==> ADP
# الشرق ==> NOUN
# الاوسط ==> ADJ
# بهدف ==> None
# ب ==> ADP
# هدف ==> NOUN
# دعم ==> NOUN
# التجارة ==> NOUN
# والسلام ==> None
# و ==> CCONJ
# السلام ==> NOUN
# فى ==> ADP
# المنطقة ==> NOUN
# . ==> PUNCT
# ونقلت ==> None
# و ==> CCONJ
# نقلت ==> VERB
# الصحيفة ==> NOUN
# عن ==> ADP
# مسئول ==> NOUN
# كبير ==> ADJ
# بادارة ==> None
# ب ==> ADP
# إدارة ==> NOUN
# بوش ==> X
# قوله ==> None
# قول ==> NOUN
# ه ==> PRON
# ان ==> SCONJ
# بوش ==> X
# سيدعو ==> None
# س ==> AUX
# يدعو ==> VERB
# الدول ==> NOUN
# العربية ==> ADJ
# فى ==> ADP
# الشرق ==> NOUN
# الاوسط ==> ADJ
# واسرائيل ==> None
# و ==> CCONJ
# إسرائيل ==> NOUN
# لانشاء ==> None
# ل ==> ADP
# إنشاء ==> NOUN
# منطقة ==> NOUN
# تجارة ==> NOUN
# حرة ==> ADJ
# خلال ==> ADP
# عشر ==> NUM
# سنوات ==> NOUN
# لدعم ==> None
# ل ==> ADP
# دعم ==> NOUN
# السلام ==> NOUN
# والامن ==> None
# و ==> CCONJ
# الأمن ==> NOUN
# فى ==> ADP
# انحاء ==> X
# المنطقة ==> NOUN
# . ==> PUNCT
# وقالت ==> None
# و ==> CCONJ
# قالت ==> VERB
# الصحيفة ==> NOUN
# ان ==> SCONJ
# بوش ==> X
# سيعلن ==> None
# س ==> AUX
# يعلن ==> VERB
# ايضا ==> ADV
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# سيرسل ==> None
# س ==> AUX
# يرسل ==> VERB
# وزير ==> NOUN
# الخارجية ==> NOUN
# كولن ==> X
# باول ==> X
# وممثل ==> None
# و ==> CCONJ
# ممثل ==> NOUN
# التجارة ==> NOUN
# الامريكى ==> ADJ
# روبرت ==> X
# زويليك ==> X
# الى ==> ADP
# المنتدى ==> NOUN
# الاقتصادى ==> ADJ
# العالمى ==> ADJ
# المقرر ==> ADJ
# عقده ==> None
# عقد ==> NOUN
# ه ==> PRON
# فى ==> ADP
# الاردن ==> NOUN
# الشهر ==> NOUN
# القادم ==> ADJ
# للاجتماع ==> None
# ل ==> ADP
# الاجتماع ==> NOUN
# مع ==> ADP
# زعماء ==> NOUN
# الشرق ==> NOUN
# الاوسط ==> ADJ
# لبحث ==> None
# ل ==> ADP
# بحث ==> NOUN
# عدد ==> NOUN
# من ==> ADP
# القضايا ==> NOUN
# . ==> PUNCT
# ويعتقد ==> None
# و ==> CCONJ
# يعتقد ==> VERB
# المحللون ==> NOUN
# ان ==> SCONJ
# التجارة ==> NOUN
# ستكون ==> None
# س ==> AUX
# تكون ==> AUX
# من ==> ADP
# الاستراتيجيات ==> NOUN
# الامريكية ==> ADJ
# للتعامل ==> None
# ل ==> ADP
# التعامل ==> NOUN
# مع ==> ADP
# منطقة ==> NOUN
# الشرق ==> NOUN
# الاوسط ==> ADJ
# . ==> PUNCT
# واضافت ==> None
# و ==> CCONJ
# أضافت ==> VERB
# الصحيفة ==> NOUN
# ان ==> SCONJ
# بوش ==> X
# سيربط ==> None
# س ==> AUX
# يربط ==> VERB
# بين ==> ADP
# اقتراح ==> NOUN
# التجارة ==> NOUN
# الحرة ==> ADJ
# والدول ==> None
# و ==> CCONJ
# الدول ==> NOUN
# التى ==> DET
# تقوم ==> VERB
# بالاصلاحات ==> None
# ب ==> ADP
# الإصلاحات ==> NOUN
# الضرورية ==> ADJ
# مثل ==> ADP
# مكافحة ==> NOUN
# الفساد ==> NOUN
# والارهاب ==> None
# و ==> CCONJ
# الإرهاب ==> NOUN
# وحماية ==> None
# و ==> CCONJ
# حماية ==> NOUN
# حقوق ==> NOUN
# الملكية ==> NOUN
# الفكرية ==> ADJ
# وتطوير ==> None
# و ==> CCONJ
# تطوير ==> NOUN
# اساليب ==> NOUN
# تجارة ==> NOUN
# جيدة ==> ADJ
# . ==> PUNCT
# وحتى ==> None
# و ==> CCONJ
# حتى ==> ADP
# الان ==> NOUN
# وقعت ==> VERB
# الولايات ==> NOUN
# المتحدة ==> ADJ
# اتفاقات ==> NOUN
# تجارة ==> NOUN
# حرة ==> ADJ
# مع ==> ADP
# اسرائيل ==> X
# والاردن ==> None
# و ==> CCONJ
# الأردن ==> NOUN
# ، ==> PUNCT
# ومن ==> None
# و ==> CCONJ
# من ==> ADP
# المتوقع ==> ADJ
# ان ==> SCONJ
# تتوصل ==> VERB
# الى ==> ADP
# اتفاق ==> NOUN
# تجارة ==> NOUN
# مع ==> ADP
# المغرب ==> NOUN
# بنهاية ==> None
# ب ==> ADP
# نهاية ==> NOUN
# العام ==> NOUN
# الحالى ==> ADJ
# . ==> PUNCT
# وقالت ==> None
# و ==> CCONJ
# قالت ==> VERB
# الصحيفة ==> NOUN
# ان ==> SCONJ
# الاقتراح ==> NOUN
# قد ==> PART
# يحظى ==> VERB
# بالترحيب ==> None
# ب ==> ADP
# الترحيب ==> NOUN
# فى ==> ADP
# المنطقة ==> NOUN
# ، ==> PUNCT
# لكنها ==> None
# لٰكن ==> CCONJ
# ها ==> PRON
# نقلت ==> VERB
# ايضا ==> ADV
# عن ==> ADP
# المسئول ==> NOUN
# الامريكى ==> ADJ
# الذى ==> DET
# اعلن ==> VERB
# الخبر ==> NOUN
# قوله ==> None
# قول ==> NOUN
# ه ==> PRON
# ان ==> SCONJ
# الرئيس ==> NOUN
# " ==> PUNCT
# يدرك ==> VERB
# ان ==> SCONJ
# هذه ==> DET
# مهمة ==> NOUN
# صعبة ==> ADJ
# وتتطلب ==> None
# و ==> CCONJ
# تتطلب ==> VERB
# قيادة ==> NOUN
# جريئة ==> ADJ
# من ==> ADP
# العديد ==> ADJ
# من ==> ADP
# الاطراف ==> NOUN
# . ==> PUNCT
# " ==> PUNCT
# كما ==> CCONJ
# نقلت ==> VERB
# الصحيفة ==> NOUN
# عن ==> ADP
# ديفيد ==> X
# ماكوفيسكى ==> X
# من ==> ADP
# معهد ==> NOUN
# واشنطن ==> X
# لسياسة ==> None
# ل ==> ADP
# سياسة ==> NOUN
# الشرق ==> NOUN
# الادنى ==> ADJ
# قوله ==> None
# قول ==> NOUN
# ه ==> PRON
# ان ==> SCONJ
# اتفاقية ==> NOUN
# التجارة ==> NOUN
# الحرة ==> ADJ
# فى ==> ADP
# المنطقة ==> NOUN
# ستكون ==> None
# س ==> AUX
# تكون ==> AUX
# مفيدة ==> ADJ
# ، ==> PUNCT
# لكنها ==> None
# لٰكن ==> CCONJ
# ها ==> PRON
# لن ==> PART
# تكون ==> AUX
# كافية ==> ADJ
# لدفع ==> None
# ل ==> ADP
# دفع ==> NOUN
# العرب ==> NOUN
# والاسرائيليين ==> None
# و ==> CCONJ
# الإسرائيليين ==> NOUN
# الى ==> ADP
# صنع ==> NOUN
# السلام ==> NOUN
# " ==> PUNCT
# فهناك ==> None
# ف ==> CCONJ
# هناك ==> ADV
# بعض ==> NOUN
# القضايا ==> NOUN
# الشائكة ==> ADJ
# للغاية ==> None
# ل ==> ADP
# الغاية ==> NOUN
# . ==> PUNCT
# " ==> PUNCT
# رامسفيلد ==> X
# يقول ==> VERB
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# لا ==> PART
# يستطيع ==> VERB
# التكهن ==> X
# بمدة ==> None
# ب ==> ADP
# مدة ==> NOUN
# بقاء ==> NOUN
# الولايات ==> NOUN
# المتحدة ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# رامسفيلد ==> X
# يقول ==> VERB
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# لا ==> PART
# يستطيع ==> VERB
# التكهن ==> NOUN
# بمدة ==> None
# ب ==> ADP
# مدة ==> NOUN
# بقاء ==> NOUN
# الولايات ==> NOUN
# المتحدة ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# واشنطن ==> X
# 9 ==> NUM
# مايو ==> NOUN
# / ==> PUNCT
# شينخوا ==> X
# / ==> PUNCT
# صرح ==> VERB
# وزير ==> NOUN
# الدفاع ==> NOUN
# الامريكى ==> ADJ
# دونالد ==> X
# رامسفيلد ==> X
# اليوم ==> NOUN
# بانه ==> None
# ب ==> ADP
# أن ==> SCONJ
# ه ==> PRON
# لا ==> PART
# يستطيع ==> VERB
# التنبؤ ==> NOUN
# بمدة ==> None
# ب ==> ADP
# مدة ==> NOUN
# بقاء ==> NOUN
# القوات ==> NOUN
# الامريكية ==> ADJ
# والبريطانية ==> None
# و ==> CCONJ
# البريطانية ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# ، ==> PUNCT
# بيد ==> CCONJ
# انها ==> None
# أن ==> SCONJ
# ها ==> PRON
# بالتأكيد ==> None
# ب ==> ADP
# التأكيد ==> NOUN
# ستزيد ==> None
# س ==> AUX
# تزيد ==> VERB
# على ==> ADP
# العام ==> NOUN
# . ==> PUNCT
# وفى ==> None
# و ==> CCONJ
# في ==> ADP
# مؤتمر ==> NOUN
# صحفى ==> ADJ
# بالبنتاجون ==> None
# ب ==> ADP
# البنتاجون ==> PROPN
# مع ==> ADP
# الجنرال ==> NOUN
# تومى ==> X
# فرانكس ==> X
# قائد ==> NOUN
# القوات ==> NOUN
# الامريكية ==> ADJ
# بالخليج ==> None
# ب ==> ADP
# الخليج ==> NOUN
# ، ==> PUNCT
# قال ==> VERB
# رامسفيلد ==> X
# ان ==> SCONJ
# مدة ==> NOUN
# العام ==> NOUN
# التى ==> DET
# اقترحتها ==> None
# اقترحت ==> VERB
# ها ==> PRON
# الولايات ==> NOUN
# المتحدة ==> ADJ
# فى ==> ADP
# مشروع ==> NOUN
# القرار ==> NOUN
# المقدم ==> ADJ
# الى ==> ADP
# مجلس ==> NOUN
# الامن ==> NOUN
# الدولى ==> ADJ
# " ==> PUNCT
# قد ==> PART
# يكون ==> AUX
# مجرد ==> NOUN
# فترة ==> NOUN
# مراجعة ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# واضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# " ==> PUNCT
# ان ==> SCONJ
# كل ==> NOUN
# من ==> DET
# يتصور ==> VERB
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# يعرف ==> VERB
# المدة ==> NOUN
# التى ==> DET
# سيستغرقها ==> None
# س ==> AUX
# يستغرق ==> VERB
# ها ==> PRON
# هذا ==> DET
# الامر ==> NOUN
# ، ==> PUNCT
# انما ==> CCONJ
# يخدع ==> VERB
# نفسه ==> None
# نفس ==> NOUN
# ه ==> PRON
# . ==> PUNCT
# انه ==> None
# إن ==> PART
# ه ==> PRON
# امر ==> NOUN
# غير ==> NOUN
# معروف ==> ADJ
# " ==> PUNCT
# . ==> PUNCT
# واشار ==> None
# و ==> CCONJ
# أشار ==> VERB
# الى ==> ADP
# ان ==> SCONJ
# الولايات ==> NOUN
# المتحدة ==> ADJ
# " ==> PUNCT
# مستعدة ==> ADJ
# للاحتفاظ ==> None
# ل ==> ADP
# الاحتفاظ ==> NOUN
# باى ==> None
# ب ==> ADP
# أي ==> ADJ
# عدد ==> NOUN
# من ==> ADP
# القوات ==> NOUN
# يكون ==> AUX
# ملائما ==> ADJ
# وضروريا ==> None
# و ==> CCONJ
# ضروريا ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# للوقت ==> None
# ل ==> ADP
# الوقت ==> NOUN
# الذى ==> DET
# يتطلبه ==> None
# يتطلب ==> VERB
# ه ==> PRON
# تهيئة ==> X
# مناخ ==> NOUN
# آمن ==> ADJ
# ييسر ==> VERB
# الامور ==> X
# " ==> PUNCT
# . ==> PUNCT
# كما ==> CCONJ
# ذكر ==> VERB
# فرانكس ==> X
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# لايستطيع ==> None
# لا ==> PART
# يستطيع ==> VERB
# التنبؤ ==> NOUN
# بالمدة ==> None
# ب ==> ADP
# المدة ==> NOUN
# التى ==> DET
# سيستغرقها ==> None
# س ==> AUX
# يستغرق ==> VERB
# ها ==> PRON
# الوجود ==> NOUN
# العسكرى ==> ADJ
# الامريكى ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# . ==> PUNCT
# واضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# " ==> PUNCT
# ان ==> SCONJ
# معرفة ==> NOUN
# ما ==> DET
# اذا ==> CCONJ
# كان ==> VERB
# المستقبل ==> NOUN
# امامنا ==> None
# أمام ==> ADP
# نا ==> PRON
# يتطلب ==> VERB
# عاما ==> NOUN
# او ==> CCONJ
# عامين ==> NOUN
# او ==> CCONJ
# ثلاثة ==> NUM
# . ==> PUNCT
# . ==> PUNCT
# . ==> PUNCT
# هو ==> PRON
# شيء ==> NOUN
# لانعرفه ==> None
# لا ==> PART
# نعرف ==> VERB
# ه ==> PRON
# بالضبط ==> None
# ب ==> ADP
# الضبط ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# تحطم ==> X
# مروحية ==> X
# امريكية ==> X
# فى ==> ADP
# العراق ==> NOUN
# ومقتل ==> None
# و ==> CCONJ
# مقتل ==> NOUN
# ثلاثة ==> NUM
# جنود ==> NOUN
# واشنطن ==> X
# 9 ==> NUM
# مايو ==> NOUN
# لقى ==> VERB
# ثلاثة ==> NUM
# جنود ==> NOUN
# امريكيين ==> ADJ
# مصرعهم ==> None
# مصرع ==> NOUN
# هم ==> PRON
# واصيب ==> None
# و ==> CCONJ
# أصيب ==> VERB
# رابع ==> X
# فى ==> ADP
# شمالى ==> X
# العراق ==> NOUN
# اليوم ==> NOUN
# عندما ==> None
# عند ==> ADP
# ما ==> DET
# سقطت ==> VERB
# المروحية ==> X
# التى ==> X
# كانت ==> VERB
# تقلهم ==> X
# ، ==> PUNCT
# وهى ==> None
# و ==> CCONJ
# هي ==> PRON
# من ==> ADP
# طراز ==> NOUN
# يواتش ==> X
# - ==> PUNCT
# 60 ==> NUM
# بلاك ==> X
# هوك ==> X
# فى ==> ADP
# نهر ==> NOUN
# دجلة ==> NOUN
# ، ==> PUNCT
# وفقا ==> NOUN
# لما ==> None
# ل ==> ADP
# ما ==> DET
# أعلنه ==> None
# أعلن ==> VERB
# ه ==> PRON
# مسئولو ==> NOUN
# البنتاجون ==> X
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# المسئولون ==> NOUN
# ان ==> SCONJ
# التقارير ==> NOUN
# الاولية ==> ADJ
# تشير ==> VERB
# الى ==> ADP
# ان ==> SCONJ
# سقوط ==> NOUN
# الطائرة ==> NOUN
# كان ==> AUX
# حادثا ==> NOUN
# وليس ==> None
# و ==> CCONJ
# ليس ==> VERB
# بسبب ==> None
# ب ==> ADP
# سبب ==> NOUN
# نيران ==> NOUN
# معادية ==> ADJ
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# احد ==> X
# المسئولين ==> NOUN
# العسكريين ==> X
# اشترط ==> VERB
# عدم ==> NOUN
# ذكر ==> NOUN
# اسمه ==> None
# اسم ==> NOUN
# ه ==> PRON
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# يبدو ==> VERB
# ان ==> SCONJ
# الطائرة ==> NOUN
# اصطدمت ==> VERB
# بخطوط ==> None
# ب ==> ADP
# خطوط ==> NOUN
# الكهرباء ==> NOUN
# قبل ==> ADP
# ان ==> SCONJ
# تسقط ==> VERB
# فى ==> ADP
# نهر ==> NOUN
# دجلة ==> NOUN
# بالقرب ==> None
# ب ==> ADP
# القرب ==> NOUN
# من ==> ADP
# مدينة ==> NOUN
# سامراء ==> X
# العراقية ==> ADJ
# . ==> PUNCT
# مصابون ==> ADJ
# عراقيون ==> ADJ
# يصلون ==> VERB
# الى ==> ADP
# السعودية ==> NOUN
# الرياض ==> NOUN
# 11 ==> NUM
# مايو ==> NOUN
# وصلت ==> VERB
# الى ==> ADP
# الرياض ==> NOUN
# مساء ==> NOUN
# اليوم ==> NOUN
# طائرة ==> NOUN
# الاخلاء ==> NOUN
# الطبى ==> ADJ
# السعودية ==> ADJ
# قادمة ==> ADJ
# من ==> ADP
# العاصمة ==> NOUN
# العراقية ==> ADJ
# بغداد ==> NOUN
# وعلى ==> None
# و ==> CCONJ
# على ==> ADP
# متنها ==> None
# متن ==> NOUN
# ها ==> PRON
# 7 ==> NUM
# مرضى ==> NOUN
# ومصابين ==> None
# و ==> CCONJ
# مصابين ==> ADJ
# ومرافقيهم ==> None
# و ==> CCONJ
# مرافقي ==> ADJ
# هم ==> PRON
# من ==> ADP
# ابناء ==> NOUN
# اسرتهم ==> None
# أسرة ==> NOUN
# هم ==> PRON
# . ==> PUNCT
# وقام ==> None
# و ==> CCONJ
# قام ==> VERB
# المستشفى ==> NOUN
# السعودى ==> ADJ
# الميدانى ==> ADJ
# التابع ==> ADJ
# للقوات ==> None
# ل ==> ADP
# القوات ==> NOUN
# المسلحة ==> ADJ
# السعودية ==> ADJ
# فى ==> ADP
# بغداد ==> NOUN
# بنقل ==> None
# ب ==> ADP
# نقل ==> NOUN
# هؤلاء ==> DET
# المرضى ==> NOUN
# ممن ==> None
# من ==> ADP
# من ==> DET
# تتطلب ==> VERB
# حالاتهم ==> None
# حالات ==> NOUN
# هم ==> PRON
# عناية ==> NOUN
# مستمرة ==> ADJ
# ورعاية ==> None
# و ==> CCONJ
# رعاية ==> NOUN
# طبية ==> ADJ
# مكثفة ==> ADJ
# حسبما ==> None
# حسب ==> ADP
# ما ==> DET
# اوردت ==> VERB
# وكالة ==> NOUN
# الانباء ==> NOUN
# السعودية ==> ADJ
# . ==> PUNCT
# ويأتى ==> None
# و ==> CCONJ
# يأتي ==> VERB
# نقل ==> NOUN
# واستقبال ==> None
# و ==> CCONJ
# استقبال ==> NOUN
# المرضى ==> NOUN
# والمصابين ==> None
# و ==> CCONJ
# المصابين ==> ADJ
# العراقيين ==> ADJ
# فى ==> ADP
# مستشفيات ==> NOUN
# المملكة ==> NOUN
# العربية ==> ADJ
# السعودية ==> ADJ
# تنفيذا ==> NOUN
# لتوجيهات ==> None
# ل ==> ADP
# توجيهات ==> NOUN
# العاهل ==> NOUN
# السعودى ==> ADJ
# الملك ==> NOUN
# فهد ==> NOUN
# بن ==> PROPN
# عبدالعزيز ==> PROPN
# والامير ==> None
# و ==> CCONJ
# الأمير ==> NOUN
# عبد ==> NOUN
# الله ==> NOUN
# بن ==> PROPN
# عبد ==> NOUN
# العزيز ==> NOUN
# ولى ==> NOUN
# العهد ==> NOUN
# نائب ==> NOUN
# رئيس ==> NOUN
# مجلس ==> NOUN
# الوزراء ==> NOUN
# ورئيس ==> None
# و ==> CCONJ
# رئيس ==> NOUN
# الحرس ==> NOUN
# الوطنى ==> ADJ
# والامير ==> None
# و ==> CCONJ
# الأمير ==> NOUN
# سلطان ==> NOUN
# بن ==> PROPN
# عبد ==> NOUN
# العزيز ==> NOUN
# النائب ==> NOUN
# الثانى ==> ADJ
# لرئيس ==> None
# ل ==> ADP
# رئيس ==> NOUN
# مجلس ==> NOUN
# الوزراء ==> NOUN
# . ==> PUNCT
# واثر ==> None
# و ==> CCONJ
# إثر ==> ADP
# وصول ==> NOUN
# المصابين ==> ADJ
# الى ==> ADP
# الرياض ==> NOUN
# ، ==> PUNCT
# تم ==> VERB
# نقلهم ==> None
# نقل ==> NOUN
# هم ==> PRON
# الى ==> ADP
# مستشفى ==> NOUN
# القوات ==> NOUN
# المسلحة ==> ADJ
# ومستشفى ==> None
# و ==> CCONJ
# مستشفى ==> NOUN
# الملك ==> NOUN
# فهد ==> NOUN
# بالحرس ==> None
# ب ==> ADP
# الحرس ==> NOUN
# الوطنى ==> ADJ
# ومستشفى ==> None
# و ==> CCONJ
# مستشفى ==> NOUN
# قوى ==> NOUN
# الامن ==> NOUN
# ومستشفى ==> None
# و ==> CCONJ
# مستشفى ==> NOUN
# الملك ==> NOUN
# خالد ==> NOUN
# التخصصى ==> ADJ
# للعيون ==> None
# ل ==> ADP
# العيون ==> NOUN
# فى ==> ADP
# الرياض ==> NOUN
# ، ==> PUNCT
# كلا ==> NOUN
# حسب ==> ADP
# حالته ==> None
# حالة ==> NOUN
# ه ==> PRON
# . ==> PUNCT
# يذكر ==> VERB
# ان ==> SCONJ
# المملكة ==> NOUN
# العربية ==> ADJ
# السعودية ==> ADJ
# والمملكة ==> None
# و ==> CCONJ
# المملكة ==> NOUN
# الاردنية ==> ADJ
# الهاشمية ==> ADJ
# كانتا ==> VERB
# قد ==> AUX
# ارسلتا ==> VERB
# مستشفيين ==> NOUN
# متنقلين ==> ADJ
# الاول ==> ADJ
# في ==> ADP
# منطقة ==> NOUN
# " ==> PUNCT
# البياع ==> NOUN
# " ==> PUNCT
# وسط ==> ADP
# بغداد ==> NOUN
# والثاني ==> None
# و ==> CCONJ
# الثاني ==> ADJ
# في ==> ADP
# منطقة ==> NOUN
# " ==> PUNCT
# ابو ==> X
# غريب ==> X
# " ==> PUNCT
# التي ==> DET
# تبعد ==> VERB
# حوالى ==> ADP
# عشرين ==> NUM
# كيلومترا ==> NOUN
# غرب ==> NOUN
# بغداد ==> NOUN
# لاخلاء ==> None
# ل ==> ADP
# إخلاء ==> NOUN
# وعلاج ==> None
# و ==> CCONJ
# علاج ==> NOUN
# الجرحى ==> NOUN
# العراقيين ==> ADJ
# . ==> PUNCT
# وتعاني ==> None
# و ==> CCONJ
# تعاني ==> VERB
# معظم ==> NOUN
# المستشفيات ==> NOUN
# والمؤسسات ==> None
# و ==> CCONJ
# المؤسسات ==> NOUN
# الصحية ==> ADJ
# العراقية ==> ADJ
# التي ==> DET
# تعرض ==> VERB
# العديد ==> ADJ
# منها ==> None
# من ==> ADP
# ها ==> PRON
# لعمليات ==> None
# ل ==> ADP
# عمليات ==> NOUN
# النهب ==> NOUN
# والسرقة ==> None
# و ==> CCONJ
# السرقة ==> NOUN
# من ==> ADP
# نقص ==> NOUN
# شديد ==> ADJ
# في ==> ADP
# الادوية ==> NOUN
# والمعدات ==> None
# و ==> CCONJ
# المعدات ==> NOUN
# الطبية ==> ADJ
# وهي ==> None
# و ==> CCONJ
# هي ==> PRON
# تبدو ==> VERB
# عاجزة ==> ADJ
# عن ==> ADP
# تقديم ==> NOUN
# الخدمات ==> NOUN
# الصحية ==> ADJ
# الملائمة ==> ADJ
# بسبب ==> None
# ب ==> ADP
# سبب ==> NOUN
# الحصار ==> NOUN
# الدولى ==> ADJ
# الذى ==> DET
# كان ==> AUX
# مفروضا ==> ADJ
# على ==> ADP
# العراق ==> NOUN
# على ==> ADP
# مدار ==> NOUN
# الـ ==> PART
# 13 ==> NUM
# عاما ==> NOUN
# الماضية ==> ADJ
# . ==> PUNCT
# 2003 ==> NUM
# - ==> PUNCT
# 05 ==> NUM
# - ==> PUNCT
# 11 ==> NUM
# - ==> PUNCT
# 20 ==> NUM
# : ==> PUNCT
# 20 ==> NUM
# : ==> PUNCT
# 18 ==> NUM
# مسؤول ==> NOUN
# امريكى ==> ADJ
# فى ==> ADP
# سريلانكا ==> X
# لاحياء ==> None
# ل ==> ADP
# إحياء ==> NOUN
# محادثات ==> NOUN
# السلام ==> NOUN
# كولومبو ==> X
# 11 ==> NUM
# مايو ==> NOUN
# وصلت ==> VERB
# الى ==> ADP
# هنا ==> ADV
# اليوم ==> NOUN
# كريستينا ==> X
# روكا ==> X
# مساعدة ==> NOUN
# وزير ==> NOUN
# الخارجية ==> ADJ
# الامريكى ==> ADJ
# لشؤون ==> None
# ل ==> ADP
# شؤون ==> NOUN
# جنوب ==> NOUN
# اسيا ==> X
# لاجراء ==> None
# ل ==> ADP
# إجراء ==> NOUN
# محادثات ==> NOUN
# مع ==> ADP
# المسؤولين ==> NOUN
# الحكوميين ==> ADJ
# تهدف ==> VERB
# الى ==> ADP
# احياء ==> NOUN
# عملية ==> NOUN
# السلام ==> NOUN
# المتوقفة ==> ADJ
# بين ==> ADP
# الحكومة ==> NOUN
# ومتمردى ==> None
# و ==> CCONJ
# متمردي ==> NOUN
# نمور ==> X
# التاميل ==> X
# الانفصاليين ==> ADJ
# . ==> PUNCT
# تلتقى ==> X
# روكا ==> X
# خلال ==> ADP
# اقامتها ==> None
# إقامة ==> NOUN
# ها ==> PRON
# هنا ==> ADV
# التى ==> DET
# تستمر ==> VERB
# ثلاثة ==> NUM
# ايام ==> NOUN
# برئيس ==> None
# ب ==> ADP
# رئيس ==> NOUN
# الوزراء ==> NOUN
# رانيل ==> X
# ويكريمسنغ ==> X
# ، ==> PUNCT
# ووزير ==> None
# و ==> CCONJ
# وزير ==> NOUN
# الشؤون ==> NOUN
# الدستورية ==> ADJ
# ج ==> X
# . ==> PUNCT
# ل ==> X
# . ==> PUNCT
# بايريس ==> X
# ، ==> PUNCT
# وغيرهما ==> None
# و ==> CCONJ
# غير ==> NOUN
# هما ==> PRON
# من ==> ADP
# مسؤولى ==> NOUN
# الحكومة ==> NOUN
# . ==> PUNCT
# كما ==> CCONJ
# تبحث ==> VERB
# معهم ==> None
# مع ==> ADP
# هم ==> PRON
# العلاقات ==> NOUN
# الثنائية ==> ADJ
# . ==> PUNCT
# توقفت ==> VERB
# محادثات ==> NOUN
# السلام ==> NOUN
# بين ==> ADP
# الحكومة ==> NOUN
# وجبهة ==> None
# و ==> CCONJ
# جبهة ==> NOUN
# نمور ==> X
# تحرير ==> NOUN
# ايلام ==> X
# التاميلية ==> X
# التى ==> DET
# تمت ==> VERB
# بوساطة ==> None
# ب ==> ADP
# وساطة ==> NOUN
# نرويجية ==> ADJ
# ، ==> PUNCT
# منذ ==> ADP
# قرر ==> VERB
# المتمردون ==> NOUN
# تعليق ==> NOUN
# المحادثات ==> NOUN
# مع ==> ADP
# الحكومة ==> NOUN
# يوم ==> NOUN
# 21 ==> NUM
# ابريل ==> NOUN
# . ==> PUNCT
# اجرى ==> VERB
# النمور ==> X
# والحكومة ==> None
# و ==> CCONJ
# الحكومة ==> NOUN
# ست ==> NUM
# جولات ==> X
# من ==> ADP
# محادثات ==> NOUN
# السلام ==> NOUN
# منذ ==> ADP
# سبتمبر ==> NOUN
# الماضى ==> ADJ
# . ==> PUNCT
# وقد ==> None
# و ==> CCONJ
# قد ==> AUX
# تنازل ==> VERB
# المتمردون ==> NOUN
# ، ==> PUNCT
# الذين ==> DET
# يحاربون ==> VERB
# القوات ==> NOUN
# الحكومية ==> ADJ
# فى ==> ADP
# شمال ==> NOUN
# وشرق ==> None
# و ==> CCONJ
# شرق ==> NOUN
# البلاد ==> NOUN
# من ==> ADP
# اجل ==> X
# انشاء ==> NOUN
# وطن ==> NOUN
# قومى ==> ADJ
# مستقل ==> ADJ
# للتاميل ==> None
# ل ==> ADP
# التاميل ==> PROPN
# ، ==> PUNCT
# عن ==> ADP
# مطلبهم ==> None
# مطلب ==> NOUN
# هم ==> PRON
# هذا ==> DET
# ، ==> PUNCT
# وقبلوا ==> None
# و ==> CCONJ
# قبلوا ==> VERB
# بحكم ==> None
# ب ==> ADP
# حكم ==> NOUN
# ذاتى ==> ADJ
# اقليمى ==> ADJ
# على ==> ADP
# النمط ==> NOUN
# الفيدرالى ==> ADJ
# داخل ==> ADP
# دولة ==> NOUN
# واحدة ==> ADJ
# . ==> PUNCT
# مشاورات ==> NOUN
# هاتفية ==> ADJ
# بين ==> ADP
# وزيري ==> NOUN
# خارجية ==> ADJ
# الصين ==> NOUN
# والسعودية ==> CCONJ
# والسعودية ==> NOUN
# بكين ==> X
# 11 ==> NUM
# مايو ==> NOUN
# أجرى ==> VERB
# وزير ==> NOUN
# الخارجية ==> NOUN
# الصينية ==> ADJ
# لى ==> X
# تشاو ==> X
# شينج ==> X
# مشاورات ==> NOUN
# عبر ==> ADP
# الهاتف ==> NOUN
# مساء ==> X
# اليوم ==> NOUN
# الاحد ==> X
# مع ==> ADP
# نظيره ==> None
# نظير ==> NOUN
# ه ==> PRON
# السعودى ==> ADJ
# سعود ==> X
# الفيصل ==> X
# تبادل ==> VERB
# خلالها ==> None
# خلال ==> ADP
# ها ==> PRON
# المسئولان ==> NOUN
# وجهات ==> NOUN
# النظر ==> NOUN
# حول ==> ADP
# المشكلة ==> NOUN
# العراقية ==> NOUN
# . ==> PUNCT
# وعرض ==> None
# و ==> CCONJ
# عرض ==> VERB
# لى ==> X
# موقف ==> NOUN
# الصين ==> NOUN
# بشأن ==> None
# ب ==> ADP
# شأن ==> NOUN
# الترتيبات ==> NOUN
# فى ==> ADP
# عراق ==> NOUN
# ما ==> DET
# بعد ==> ADP
# الحرب ==> NOUN
# واعادة ==> None
# و ==> CCONJ
# إعادة ==> NOUN
# الاعمار ==> X
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# ان ==> SCONJ
# الصين ==> NOUN
# تأمل ==> VERB
# ان ==> SCONJ
# يتحقق ==> X
# الاستقرار ==> NOUN
# فى ==> ADP
# الوضع ==> NOUN
# داخل ==> ADP
# العراق ==> NOUN
# فى ==> ADP
# اسرع ==> X
# وقت ==> NOUN
# ممكن ==> ADJ
# . ==> PUNCT
# وأضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# ان ==> SCONJ
# الصين ==> NOUN
# ستقدم ==> None
# س ==> AUX
# تقدم ==> VERB
# مساعدات ==> NOUN
# انسانية ==> ADJ
# اضافية ==> X
# الى ==> ADP
# الشعب ==> NOUN
# العراقى ==> ADJ
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# لى ==> X
# ان ==> SCONJ
# الترتيبات ==> NOUN
# فى ==> ADP
# عراق ==> NOUN
# ما ==> DET
# بعد ==> ADP
# الحرب ==> NOUN
# تمثل ==> VERB
# مشكلة ==> NOUN
# بالغة ==> ADJ
# التعقيد ==> NOUN
# نظرا ==> NOUN
# لأن ==> None
# ل ==> ADP
# أن ==> SCONJ
# مثل ==> ADP
# هذه ==> DET
# الترتيبات ==> NOUN
# يجب ==> VERB
# ان ==> SCONJ
# تعمل ==> VERB
# على ==> ADP
# صيانة ==> NOUN
# المصالح ==> NOUN
# الجوهرية ==> ADJ
# للشعب ==> None
# ل ==> ADP
# الشعب ==> NOUN
# العراقى ==> ADJ
# والمحافظة ==> None
# و ==> CCONJ
# المحافظة ==> NOUN
# على ==> ADP
# السلام ==> NOUN
# والاستقرار ==> None
# و ==> CCONJ
# الاستقرار ==> NOUN
# فى ==> ADP
# المنطقة ==> NOUN
# ومن ==> None
# و ==> CCONJ
# من ==> ADP
# ثم ==> ADV
# فانه ==> None
# ف ==> CCONJ
# إن ==> SCONJ
# ه ==> PRON
# يتعين ==> VERB
# التعامل ==> NOUN
# مع ==> ADP
# هذه ==> DET
# القضية ==> NOUN
# وفقا ==> NOUN
# لروح ==> None
# ل ==> ADP
# روح ==> NOUN
# ميثاق ==> NOUN
# الامم ==> NOUN
# المتحدة ==> ADJ
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# ان ==> SCONJ
# هنالك ==> ADV
# اجماعا ==> NOUN
# مشتركا ==> ADJ
# بين ==> ADP
# الصين ==> NOUN
# والسعودية ==> None
# و ==> CCONJ
# السعودية ==> NOUN
# فى ==> ADP
# هذا ==> DET
# الشأن ==> NOUN
# وان ==> None
# و ==> CCONJ
# إن ==> SCONJ
# الصين ==> NOUN
# سوف ==> AUX
# تتعاون ==> VERB
# مع ==> ADP
# الاطراف ==> NOUN
# المعنية ==> ADJ
# بما ==> None
# ب ==> ADP
# ما ==> DET
# فيها ==> None
# في ==> ADP
# ها ==> PRON
# السعودية ==> NOUN
# وسوف ==> None
# و ==> CCONJ
# سوف ==> AUX
# تضطلع ==> VERB
# بدور ==> None
# ب ==> ADP
# دور ==> NOUN
# نشط ==> ADJ
# فى ==> ADP
# اعادة ==> NOUN
# الاعمار ==> NOUN
# فى ==> ADP
# عراق ==> NOUN
# ما ==> DET
# بعد ==> ADP
# الحرب ==> NOUN
# . ==> PUNCT
# ومن ==> None
# و ==> CCONJ
# من ==> ADP
# جانبه ==> None
# جانب ==> NOUN
# ه ==> PRON
# قال ==> VERB
# سعود ==> X
# الفيصل ==> X
# ان ==> SCONJ
# الموقف ==> NOUN
# الامنى ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# يدعو ==> VERB
# للقلق ==> None
# ل ==> ADP
# القلق ==> NOUN
# وانه ==> None
# و ==> CCONJ
# إن ==> SCONJ
# ه ==> PRON
# يتعين ==> VERB
# على ==> ADP
# مجلس ==> NOUN
# الامن ==> NOUN
# الدولى ==> ADJ
# ان ==> SCONJ
# يلعب ==> VERB
# دورا ==> NOUN
# رئيسيا ==> ADJ
# فى ==> ADP
# تحقيق ==> NOUN
# الامن ==> NOUN
# والاستقرار ==> None
# و ==> CCONJ
# الاستقرار ==> NOUN
# فى ==> ADP
# العراق ==> NOUN
# لما ==> None
# ل ==> ADP
# ما ==> DET
# يمكن ==> VERB
# ان ==> SCONJ
# يؤدى ==> VERB
# اليه ==> None
# إلي ==> ADP
# ه ==> PRON
# ذلك ==> DET
# من ==> ADP
# تحقيق ==> NOUN
# سيادة ==> NOUN
# العراق ==> NOUN
# وضمان ==> None
# و ==> CCONJ
# ضمان ==> NOUN
# سلامة ==> NOUN
# اراضيه ==> None
# أراضي ==> NOUN
# ه ==> PRON
# واحلال ==> None
# و ==> CCONJ
# إحلال ==> NOUN
# السلام ==> NOUN
# والامن ==> None
# و ==> CCONJ
# الأمن ==> NOUN
# فى ==> ADP
# المنطقة ==> NOUN
# . ==> PUNCT
# وأعرب ==> None
# و ==> CCONJ
# أعرب ==> VERB
# الفيصل ==> NOUN
# عن ==> ADP
# تعاطفه ==> None
# تعاطف ==> NOUN
# ه ==> PRON
# وقلقه ==> None
# و ==> CCONJ
# قلق ==> NOUN
# ه ==> PRON
# للصين ==> None
# ل ==> ADP
# الصين ==> NOUN
# والتى ==> None
# و ==> CCONJ
# التي ==> DET
# قد ==> AUX
# تأثرت ==> VERB
# من ==> ADP
# جراء ==> ADP
# تفشي ==> NOUN
# وباء ==> NOUN
# الالتهاب ==> NOUN
# الرئوى ==> ADJ
# الحاد ==> ADJ
# ( ==> PUNCT
# سارس ==> X
# ) ==> PUNCT
# قائلا ==> ADJ
# ان ==> SCONJ
# الشعب ==> NOUN
# السعودي ==> ADJ
# سيقف ==> None
# س ==> AUX
# يقف ==> VERB
# الى ==> ADP
# جانب ==> NOUN
# الشعب ==> NOUN
# الصيني ==> ADJ
# فى ==> ADP
# حربه ==> None
# حرب ==> NOUN
# ه ==> PRON
# ضد ==> ADP
# وباء ==> NOUN
# السارس ==> X
# وان ==> None
# و ==> CCONJ
# إن ==> SCONJ
# الحكومة ==> NOUN
# الصينية ==> ADJ
# ستقود ==> None
# س ==> AUX
# تقود ==> VERB
# الشعب ==> NOUN
# الصينى ==> ADJ
# الى ==> ADP
# تحقيق ==> NOUN
# النصر ==> NOUN
# على ==> ADP
# السارس ==> X
# . ==> PUNCT
# كبير ==> ADJ
# مفاوضى ==> NOUN
# التاميل ==> X
# يغادر ==> VERB
# للعلاج ==> ADP
# للعلاج ==> NOUN
# كولومبو ==> X
# 11 ==> NUM
# مايو ==> NOUN
# ذكرت ==> VERB
# السفارة ==> NOUN
# النرويجية ==> ADJ
# هنا ==> ADV
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# من ==> ADP
# المقرر ==> ADJ
# ان ==> SCONJ
# يغادر ==> VERB
# انطون ==> X
# بالاسينجام ==> X
# كبير ==> ADJ
# مفاوضى ==> NOUN
# نمور ==> X
# التاميل ==> X
# بسريلانكا ==> None
# ب ==> ADP
# سريلانكا ==> X
# هنا ==> ADV
# صباح ==> NOUN
# الاثنين ==> NOUN
# الباكر ==> ADJ
# الى ==> ADP
# لندن ==> X
# لتلقى ==> None
# ل ==> ADP
# تلقي ==> NOUN
# العلاج ==> NOUN
# هناك ==> ADV
# . ==> PUNCT
# يذكر ==> VERB
# ان ==> SCONJ
# بالاسينجام ==> X
# 64 ==> NUM
# عاما ==> NOUN
# ، ==> PUNCT
# كبير ==> ADJ
# مفاوضى ==> NOUN
# جبهة ==> NOUN
# نمور ==> X
# تحرير ==> NOUN
# ايلام ==> X
# التاميلية ==> X
# المتمردة ==> X
# ، ==> PUNCT
# اجريت ==> VERB
# له ==> None
# ل ==> ADP
# ه ==> PRON
# عملية ==> NOUN
# زراعة ==> NOUN
# كلى ==> X
# ويقيم ==> None
# و ==> CCONJ
# يقيم ==> VERB
# فى ==> ADP
# لندن ==> X
# . ==> PUNCT
# وقد ==> None
# و ==> CCONJ
# قد ==> AUX
# حضر ==> VERB
# على ==> ADP
# متن ==> X
# مروحية ==> X
# حربية ==> ADJ
# تابعة ==> ADJ
# لسريلانكا ==> None
# ل ==> ADP
# سريلانكا ==> X
# الى ==> ADP
# مطار ==> NOUN
# كولومبو ==> X
# الدولى ==> ADJ
# قادما ==> ADJ
# من ==> ADP
# بلدة ==> NOUN
# كيلينوتششى ==> X
# الشمالية ==> ADJ
# التى ==> DET
# يسيطر ==> VERB
# عليها ==> None
# علي ==> ADP
# ها ==> PRON
# المتمردون ==> NOUN
# بعد ==> ADP
# ظهر ==> NOUN
# اليوم ==> NOUN
# . ==> PUNCT
# كان ==> VERB
# كبير ==> ADJ
# المفاوضين ==> NOUN
# قد ==> AUX
# وصل ==> VERB
# الى ==> ADP
# سريلانكا ==> X
# فى ==> ADP
# نهاية ==> NOUN
# ابريل ==> NOUN
# ، ==> PUNCT
# عقب ==> ADP
# اعلان ==> NOUN
# المتمردين ==> NOUN
# يوم ==> NOUN
# 21 ==> NUM
# ابريل ==> NOUN
# تعليق ==> NOUN
# محادثات ==> NOUN
# السلام ==> NOUN
# مع ==> ADP
# الحكومة ==> NOUN
# التى ==> DET
# تمت ==> VERB
# بوساطة ==> None
# ب ==> ADP
# وساطة ==> NOUN
# نرويجية ==> ADJ
# . ==> PUNCT
# وذكرت ==> None
# و ==> CCONJ
# ذكرت ==> VERB
# السفارة ==> NOUN
# النرويجية ==> ADJ
# انها ==> None
# أن ==> SCONJ
# ها ==> PRON
# تلقت ==> VERB
# اخطارا ==> NOUN
# من ==> ADP
# النمور ==> NOUN
# " ==> PUNCT
# بأن ==> None
# ب ==> ADP
# أن ==> SCONJ
# السيد ==> NOUN
# انطون ==> X
# بالاسينجام ==> X
# يعانى ==> VERB
# من ==> ADP
# مشكلة ==> NOUN
# صحية ==> ADJ
# عقب ==> ADP
# العملية ==> NOUN
# ، ==> PUNCT
# وانه ==> None
# و ==> CCONJ
# إن ==> SCONJ
# ه ==> PRON
# بحاجة ==> None
# ب ==> ADP
# حاجة ==> NOUN
# الى ==> ADP
# علاج ==> NOUN
# ومتابعة ==> None
# و ==> CCONJ
# متابعة ==> NOUN
# من ==> ADP
# جانب ==> NOUN
# الاطباء ==> NOUN
# المقيمين ==> ADJ
# فى ==> ADP
# لندن ==> X
# . ==> PUNCT
# خبير ==> NOUN
# من ==> ADP
# منظمة ==> NOUN
# الصحة ==> NOUN
# العالمية ==> ADJ
# يزور ==> VERB
# قرية ==> NOUN
# الحجر ==> X
# الصحى ==> ADJ
# الصينية ==> ADJ
# شيجياتشوانج ==> X
# 11 ==> NUM
# مايو ==> NOUN
# قام ==> VERB
# فريق ==> NOUN
# من ==> ADP
# منظمة ==> NOUN
# الصحة ==> NOUN
# العالمية ==> ADJ
# اليوم ==> NOUN
# الاحد ==> X
# باول ==> None
# ب ==> ADP
# أول ==> ADJ
# زيارة ==> NOUN
# لقرية ==> None
# ل ==> ADP
# قرية ==> NOUN
# الحجر ==> X
# الصحى ==> ADJ
# الصينية ==> X
# المقامة ==> X
# فى ==> ADP
# مقاطعة ==> NOUN
# خبى ==> X
# فى ==> ADP
# شمال ==> NOUN
# الصين ==> X
# . ==> PUNCT
# يذكر ==> VERB
# ان ==> SCONJ
# المقاطعة ==> NOUN
# التى ==> DET
# تعد ==> VERB
# موطنا ==> NOUN
# جيدا ==> ADJ
# لعدد ==> None
# ل ==> ADP
# عدد ==> NOUN
# كبير ==> ADJ
# من ==> ADP
# سكان ==> NOUN
# بكين ==> X
# من ==> ADP
# العمال ==> NOUN
# المهاجرين ==> NOUN
# قد ==> AUX
# جذب ==> VERB
# اهتمام ==> NOUN
# منظمة ==> NOUN
# الصحة ==> NOUN
# العالمية ==> ADJ
# بسبب ==> None
# ب ==> ADP
# سبب ==> NOUN
# تنامى ==> NOUN
# عدد ==> NOUN
# حالات ==> NOUN
# مرض ==> NOUN
# الالتهاب ==> NOUN
# الرئوي ==> ADJ
# اللانمطى ==> ADJ
# الحاد ==> ADJ
# / ==> PUNCT
# سارس ==> X
# / ==> PUNCT
# خلال ==> ADP
# الاسابيع ==> NOUN
# القليلة ==> ADJ
# الماضية ==> ADJ
# . ==> PUNCT
# وبحلول ==> None
# و ==> CCONJ
# ب ==> ADP
# حلول ==> NOUN
# الساعة ==> NOUN
# العاشرة ==> ADJ
# من ==> ADP
# صباح ==> NOUN
# اليوم ==> NOUN
# الاحد ==> NOUN
# بالتوقيت ==> None
# ب ==> ADP
# التوقيت ==> NOUN
# المحلي ==> ADJ
# ، ==> PUNCT
# أعلنت ==> VERB
# خبي ==> X
# عن ==> ADP
# وجود ==> NOUN
# 166 ==> NUM
# حالة ==> NOUN
# سارس ==> X
# و ==> CCONJ
# ثماني ==> NUM
# وفيات ==> NOUN
# . ==> PUNCT
# ودخل ==> None
# و ==> CCONJ
# دخل ==> VERB
# جيمس ==> X
# ماجواير ==> X
# عضو ==> NOUN
# فريق ==> NOUN
# خبراء ==> NOUN
# منظمة ==> NOUN
# الصحة ==> NOUN
# الذى ==> DET
# يتفقد ==> VERB
# جهود ==> NOUN
# مكافحة ==> NOUN
# سارس ==> X
# و ==> CCONJ
# علاجه ==> None
# علاج ==> NOUN
# ه ==> PRON
# فى ==> ADP
# المقاطعة ==> NOUN
# دخل ==> VERB
# الى ==> ADP
# القرية ==> NOUN
# التى ==> DET
# تقع ==> VERB
# على ==> ADP
# بعد ==> NOUN
# 60 ==> NUM
# كيلومترا ==> NOUN
# عن ==> ADP
# عاصمة ==> NOUN
# المقاطعة ==> NOUN
# شيجياتشوانج ==> X
# . ==> PUNCT
# ويبلغ ==> None
# و ==> CCONJ
# يبلغ ==> VERB
# تعداد ==> NOUN
# سكان ==> NOUN
# القرية ==> NOUN
# حوالي ==> ADP
# ألف ==> NUM
# نسمة ==> NOUN
# وتم ==> None
# و ==> CCONJ
# تم ==> VERB
# عزلها ==> None
# عزل ==> NOUN
# ها ==> PRON
# منذ ==> ADP
# الاول ==> ADJ
# من ==> ADP
# مايو ==> NOUN
# عندما ==> CCONJ
# تم ==> VERB
# تشخيص ==> NOUN
# حالة ==> NOUN
# ثلاثة ==> NUM
# قرويين ==> NOUN
# بما ==> None
# ب ==> ADP
# ما ==> DET
# يشتبه ==> VERB
# فى ==> ADP
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# سارس ==> X
# . ==> PUNCT
# وذكر ==> None
# و ==> CCONJ
# ذكر ==> VERB
# مسؤولون ==> NOUN
# محليون ==> ADJ
# أنه ==> None
# أن ==> SCONJ
# ه ==> PRON
# خلال ==> ADP
# فترة ==> NOUN
# العزل ==> NOUN
# التى ==> DET
# دامت ==> VERB
# 15 ==> NUM
# يوما ==> NOUN
# ، ==> PUNCT
# سمح ==> VERB
# للقرويين ==> None
# ل ==> ADP
# القرويين ==> NOUN
# بالبقاء ==> None
# ب ==> ADP
# البقاء ==> NOUN
# فى ==> ADP
# منازلهم ==> None
# منازل ==> NOUN
# هم ==> PRON
# و ==> CCONJ
# الامتناع ==> NOUN
# عن ==> ADP
# زيارة ==> NOUN
# الاقارب ==> NOUN
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# ماجواير ==> X
# الذى ==> DET
# كان ==> VERB
# يسير ==> None
# يسير ==> VERB
# عبر ==> ADP
# القرية ==> NOUN
# الهادئة ==> ADJ
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# أعجب ==> VERB
# بتعاون ==> None
# ب ==> ADP
# تعاون ==> NOUN
# القرويين ==> NOUN
# الجيد ==> ADJ
# مع ==> ADP
# النظام ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# وأضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# " ==> PUNCT
# إنها ==> None
# إن ==> PART
# ها ==> PRON
# المسئولية ==> NOUN
# الشخصية ==> ADJ
# التى ==> DET
# تجعل ==> VERB
# النظام ==> NOUN
# يعمل ==> VERB
# " ==> PUNCT
# . ==> PUNCT
# وصرح ==> None
# و ==> CCONJ
# صرح ==> VERB
# مسئول ==> NOUN
# محلى ==> ADJ
# لماجواير ==> X
# بأن ==> None
# ب ==> ADP
# أن ==> SCONJ
# حكومة ==> NOUN
# المنطقة ==> NOUN
# وفرت ==> VERB
# جميع ==> NOUN
# احتياجات ==> X
# القرويين ==> NOUN
# اليومية ==> ADJ
# خلال ==> ADP
# فترة ==> NOUN
# العزل ==> NOUN
# بالمجان ==> None
# ب ==> ADP
# المجان ==> ADJ
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# " ==> PUNCT
# وبذلك ==> None
# و ==> CCONJ
# ب ==> ADP
# ذٰلك ==> DET
# قدمنا ==> X
# أكثر ==> ADJ
# من ==> ADP
# ثلاثة ==> NUM
# آلاف ==> NUM
# كيلوجرام ==> NOUN
# من ==> ADP
# البيض ==> NOUN
# للقرويين ==> None
# ل ==> ADP
# القرويين ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# اجمالى ==> NOUN
# ضحايا ==> NOUN
# كارثة ==> NOUN
# طائرة ==> NOUN
# الكونغو ==> X
# قد ==> PART
# يتجاوز ==> VERB
# 14 ==> NUM
# شخصا ==> NOUN
# كينشاسا ==> X
# 11 ==> NUM
# مايو ==> NOUN
# صرح ==> VERB
# كيكايا ==> X
# بين ==> X
# كاروبى ==> X
# وزير ==> NOUN
# الاعلام ==> NOUN
# فى ==> ADP
# جمهورية ==> NOUN
# الكونغو ==> X
# الديمقراطية ==> ADJ
# هنا ==> ADV
# اليوم ==> NOUN
# ان ==> SCONJ
# اجمالى ==> NOUN
# ضحايا ==> NOUN
# الكارثة ==> NOUN
# الجوية ==> ADJ
# التى ==> DET
# وقعت ==> VERB
# مؤخرا ==> ADJ
# ، ==> PUNCT
# قد ==> PART
# يتجاوز ==> VERB
# الاربع ==> NUM
# عشرة ==> NUM
# التى ==> DET
# اعلن ==> VERB
# عنها ==> None
# عن ==> ADP
# ها ==> PRON
# حتى ==> ADP
# الآن ==> NOUN
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# دائما ==> ADJ
# مايكون ==> X
# هناك ==> ADV
# احصاء ==> X
# اولى ==> X
# ، ==> PUNCT
# ونحن ==> None
# و ==> CCONJ
# نحن ==> PRON
# نعتقد ==> X
# بان ==> None
# ب ==> ADP
# أن ==> SCONJ
# هناك ==> ADV
# قتلى ==> X
# اكثر ==> ADJ
# من ==> ADP
# مجرد ==> NOUN
# ال ==> PART
# 14 ==> NUM
# الذين ==> X
# اعلن ==> VERB
# عنهم ==> None
# عن ==> ADP
# هم ==> PRON
# ، ==> PUNCT
# بيد ==> CCONJ
# اننا ==> None
# أن ==> SCONJ
# نا ==> PRON
# نقوم ==> X
# بالتحقيق ==> None
# ب ==> ADP
# التحقيق ==> NOUN
# للتأكد ==> None
# ل ==> ADP
# التأكد ==> NOUN
# من ==> ADP
# ذلك ==> DET
# . ==> PUNCT
# كان ==> VERB
# كاروبى ==> X
# قد ==> AUX
# صرح ==> VERB
# فى ==> ADP
# وقت ==> NOUN
# سابق ==> NOUN
# اليوم ==> NOUN
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# تأكد ==> VERB
# مصرع ==> X
# 7 ==> NUM
# اشخاص ==> NOUN
# عقب ==> ADP
# ان ==> SCONJ
# لفظتهم ==> None
# لفظت ==> VERB
# هم ==> PRON
# خارجا ==> NOUN
# طائرة ==> NOUN
# البضائع ==> NOUN
# اليوشن ==> X
# - ==> PUNCT
# 76 ==> NUM
# التى ==> DET
# كانت ==> VERB
# تقل ==> X
# جنودا ==> NOUN
# من ==> ADP
# كينشاسا ==> X
# الى ==> ADP
# مقاطعة ==> NOUN
# كاتنجا ==> X
# الجنوبية ==> ADJ
# مساء ==> X
# الخميس ==> NOUN
# . ==> PUNCT
# وذكرت ==> None
# و ==> CCONJ
# ذكرت ==> VERB
# الانباء ==> X
# ان ==> SCONJ
# الباب ==> NOUN
# الخلفى ==> ADJ
# للطائرة ==> None
# ل ==> ADP
# الطائرة ==> NOUN
# انفتح ==> VERB
# فجأة ==> NOUN
# على ==> ADP
# ارتفاع ==> NOUN
# 2200 ==> NUM
# متر ==> NOUN
# فوق ==> ADP
# مدينة ==> NOUN
# مبوجى ==> X
# - ==> PUNCT
# مايى ==> X
# . ==> PUNCT
# وصرح ==> None
# و ==> CCONJ
# صرح ==> VERB
# وزير ==> NOUN
# الدفاع ==> NOUN
# الكونغولى ==> ADJ
# المشرف ==> X
# على ==> ADP
# القوات ==> NOUN
# الجوية ==> ADJ
# اليوم ==> NOUN
# ان ==> SCONJ
# 14 ==> NUM
# شخصا ==> NOUN
# فقط ==> ADV
# اعتبروا ==> VERB
# حتى ==> ADP
# الان ==> NOUN
# فى ==> ADP
# عداد ==> X
# المفقودين ==> ADJ
# ، ==> PUNCT
# من ==> ADP
# بينهم ==> None
# بين ==> ADP
# هم ==> PRON
# 7 ==> NUM
# من ==> ADP
# رجال ==> NOUN
# الشرطة ==> NOUN
# و ==> CCONJ
# 7 ==> NUM
# مدنيين ==> ADJ
# . ==> PUNCT
# كما ==> CCONJ
# كشف ==> VERB
# اليوم ==> NOUN
# وزير ==> NOUN
# الصحة ==> NOUN
# الكونغولى ==> ADJ
# مامبا ==> X
# شاكو ==> X
# عن ==> ADP
# ان ==> SCONJ
# مالا ==> X
# يقل ==> VERB
# عن ==> ADP
# 30 ==> NUM
# شخصا ==> NOUN
# علم ==> VERB
# انهم ==> None
# أن ==> SCONJ
# هم ==> PRON
# عادوا ==> VERB
# بسلامة ==> None
# ب ==> ADP
# سلامة ==> NOUN
# مع ==> ADP
# طائرة ==> NOUN
# البضائع ==> NOUN
# روسية ==> ADJ
# الصنع ==> NOUN
# التى ==> DET
# عادت ==> VERB
# الى ==> ADP
# مطار ==> NOUN
# كينشاسا ==> X
# مساء ==> NOUN
# الخميس ==> NOUN
# عقب ==> ADP
# انفتاح ==> NOUN
# الباب ==> NOUN
# الخلفى ==> ADJ
# للطائرة ==> None
# ل ==> ADP
# الطائرة ==> NOUN
# فجأة ==> NOUN
# ليلفظ ==> None
# ل ==> CCONJ
# يلفظ ==> VERB
# الركاب ==> NOUN
# الى ==> ADP
# الهواء ==> NOUN
# على ==> ADP
# ارتفاع ==> NOUN
# 2200 ==> NUM
# متر ==> NOUN
# فوق ==> ADP
# الدولة ==> NOUN
# شاسعة ==> ADJ
# الاراضى ==> NOUN
# بوسط ==> None
# ب ==> ADP
# وسط ==> NOUN
# افريقيا ==> X
# . ==> PUNCT
# ويحقق ==> None
# و ==> CCONJ
# يحقق ==> VERB
# الجيش ==> NOUN
# فى ==> ADP
# كوريا ==> X
# الديمقراطية ==> X
# حاليا ==> ADJ
# فى ==> ADP
# الحادث ==> NOUN
# ، ==> PUNCT
# بيد ==> CCONJ
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# لم ==> PART
# يصدر ==> VERB
# بيان ==> NOUN
# رسمى ==> ADJ
# فى ==> ADP
# هذا ==> DET
# الصدد ==> NOUN
# حتى ==> ADP
# الآن ==> NOUN
# . ==> PUNCT
# وقد ==> None
# و ==> CCONJ
# قد ==> AUX
# اعرب ==> VERB
# مسؤولان ==> NOUN
# بمطار ==> None
# ب ==> ADP
# مطار ==> NOUN
# كينشاسا ==> X
# الدولى ==> ADJ
# من ==> ADP
# قبل ==> ADP
# عن ==> ADP
# خشيتهم ==> None
# خشية ==> NOUN
# هم ==> PRON
# من ==> ADP
# ان ==> SCONJ
# عدد ==> NOUN
# القتلى ==> NOUN
# فى ==> ADP
# الحادث ==> NOUN
# قد ==> PART
# لايقل ==> X
# عن ==> ADP
# 120 ==> NUM
# شخصا ==> NOUN
# . ==> PUNCT
# مستشفى ==> NOUN
# فى ==> ADP
# بكين ==> X
# يعلن ==> VERB
# مغادرة ==> NOUN
# جميع ==> NOUN
# مرضى ==> NOUN
# سارس ==> X
# من ==> ADP
# الاجانب ==> NOUN
# بعد ==> ADP
# شفائهم ==> NOUN
# شفائهم ==> PRON
# بكين ==> X
# 11 ==> NUM
# مايو ==> NOUN
# أعلن ==> VERB
# مستشفى ==> NOUN
# اتحاد ==> NOUN
# كليات ==> NOUN
# الطب ==> NOUN
# في ==> ADP
# بكين ==> X
# أمس ==> ADV
# السبت ==> NOUN
# أن ==> SCONJ
# المرضى ==> NOUN
# الستة ==> NUM
# من ==> ADP
# الاجانب ==> NOUN
# المصابين ==> ADJ
# بوباء ==> None
# ب ==> ADP
# وباء ==> NOUN
# الالتهاب ==> NOUN
# الرئوى ==> ADJ
# الحاد ==> ADJ
# / ==> PUNCT
# سارس ==> X
# / ==> PUNCT
# قد ==> AUX
# غادروا ==> VERB
# المستشفى ==> NOUN
# بعدما ==> None
# بعد ==> ADP
# ما ==> DET
# تماثلوا ==> VERB
# للشفاء ==> None
# ل ==> ADP
# الشفاء ==> NOUN
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# المتحدث ==> NOUN
# باسم ==> None
# ب ==> ADP
# اسم ==> NOUN
# المستشفى ==> NOUN
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# منذ ==> ADP
# التاسع ==> ADJ
# من ==> ADP
# ابريل ==> NOUN
# وعندما ==> None
# و ==> CCONJ
# عندما ==> CCONJ
# أعلنت ==> VERB
# الحكومة ==> NOUN
# تخصيص ==> NOUN
# هذا ==> DET
# المستشفي ==> NOUN
# لاستقبال ==> None
# ل ==> ADP
# استقبال ==> NOUN
# مرضى ==> NOUN
# السارس ==> X
# من ==> ADP
# الاجانب ==> ADJ
# فانه ==> None
# ف ==> CCONJ
# إن ==> SCONJ
# ه ==> PRON
# قد ==> AUX
# جرى ==> VERB
# ادخال ==> NOUN
# ستة ==> NUM
# من ==> ADP
# هؤلاء ==> DET
# الاجانب ==> NOUN
# وهما ==> None
# و ==> CCONJ
# هما ==> PRON
# كنديان ==> NOUN
# واربعة ==> None
# و ==> CCONJ
# أربعة ==> NUM
# امريكيين ==> NOUN
# الى ==> ADP
# المستشفى ==> NOUN
# باعتبارهم ==> None
# ب ==> ADP
# اعتبار ==> NOUN
# هم ==> PRON
# من ==> ADP
# الحالات ==> NOUN
# المشتبه ==> ADJ
# فى ==> ADP
# اصابتها ==> None
# إصابة ==> NOUN
# ها ==> PRON
# بالسارس ==> None
# ب ==> ADP
# السارس ==> X
# . ==> PUNCT
# ولدى ==> None
# و ==> CCONJ
# لدى ==> ADP
# المستشفى ==> NOUN
# حاليا ==> ADJ
# 17 ==> NUM
# سريرا ==> NOUN
# لمرضى ==> None
# ل ==> ADP
# مرضى ==> NOUN
# السارس ==> X
# من ==> ADP
# الاجانب ==> NOUN
# كما ==> CCONJ
# ان ==> SCONJ
# الاطباء ==> NOUN
# المعالجين ==> X
# والمرضى ==> None
# و ==> CCONJ
# المرضى ==> NOUN
# يتحدثون ==> VERB
# الانجليزية ==> NOUN
# بطلاقة ==> None
# ب ==> ADP
# طلاقة ==> NOUN
# . ==> PUNCT
# وقد ==> None
# و ==> CCONJ
# قد ==> AUX
# ادخل ==> VERB
# الى ==> ADP
# المستشفى ==> NOUN
# ايضا ==> ADV
# مواطن ==> NOUN
# هندى ==> ADJ
# يعانى ==> VERB
# من ==> ADP
# اعراض ==> X
# شبيهة ==> ADJ
# باعراض ==> None
# ب ==> ADP
# أعراض ==> NOUN
# السارس ==> X
# بيد ==> CCONJ
# ان ==> SCONJ
# الاطباء ==> NOUN
# قد ==> AUX
# شخصوا ==> VERB
# حالته ==> None
# حالة ==> NOUN
# ه ==> PRON
# على ==> ADP
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# مصاب ==> ADJ
# بحمى ==> None
# ب ==> ADP
# حمى ==> NOUN
# التيفود ==> NOUN
# . ==> PUNCT
# وسيتم ==> None
# و ==> CCONJ
# س ==> AUX
# يتم ==> VERB
# نقل ==> NOUN
# هذا ==> DET
# المريض ==> NOUN
# الى ==> ADP
# مستشفى ==> NOUN
# اخر ==> ADJ
# لتلقى ==> None
# ل ==> ADP
# تلقي ==> NOUN
# المزيد ==> NOUN
# من ==> ADP
# العلاج ==> NOUN
# قريبا ==> ADJ
# حسبما ==> None
# حسب ==> ADP
# ما ==> DET
# ذكر ==> VERB
# المتحدث ==> NOUN
# . ==> PUNCT
# تقرير ==> NOUN
# أخبارى ==> X
# : ==> PUNCT
# الشركات ==> NOUN
# الهندية ==> NOUN
# تتطلع ==> VERB
# للفوز ==> None
# ل ==> ADP
# الفوز ==> NOUN
# بعقود ==> None
# ب ==> ADP
# عقود ==> NOUN
# لاعادة ==> None
# ل ==> ADP
# إعادة ==> NOUN
# إعمار ==> NOUN
# العراق ==> NOUN
# تقرير ==> NOUN
# أخبارى ==> X
# : ==> PUNCT
# الشركات ==> NOUN
# الهندية ==> NOUN
# تتطلع ==> VERB
# للفوز ==> None
# ل ==> ADP
# الفوز ==> NOUN
# بعقود ==> None
# ب ==> ADP
# عقود ==> NOUN
# لاعادة ==> None
# ل ==> ADP
# إعادة ==> NOUN
# إعمار ==> NOUN
# العراق ==> NOUN
# نيو ==> X
# دلهى ==> X
# 11 ==> NUM
# مايو ==> NOUN
# / ==> PUNCT
# شينخوا ==> X
# / ==> PUNCT
# انتهت ==> VERB
# الحرب ==> NOUN
# على ==> ADP
# العراق ==> NOUN
# وتحول ==> None
# و ==> CCONJ
# تحول ==> VERB
# انتباه ==> X
# العالم ==> NOUN
# إلى ==> ADP
# القضية ==> NOUN
# الهامة ==> ADJ
# وهى ==> None
# و ==> CCONJ
# هي ==> PRON
# إعادة ==> NOUN
# بناء ==> NOUN
# البلاد ==> NOUN
# ما ==> DET
# بعد ==> ADP
# الحرب ==> NOUN
# . ==> PUNCT
# وستشمل ==> None
# و ==> CCONJ
# س ==> AUX
# تشمل ==> VERB
# عملية ==> NOUN
# إعادة ==> NOUN
# الاعمار ==> NOUN
# إنشاء ==> NOUN
# كثير ==> ADJ
# من ==> ADP
# المنشآت ==> NOUN
# المدنية ==> ADJ
# الاساسية ==> ADJ
# فى ==> ADP
# العراق ==> NOUN
# . ==> PUNCT
# وتشير ==> None
# و ==> CCONJ
# تشير ==> VERB
# تقديرات ==> NOUN
# هندية ==> ADJ
# الى ==> ADP
# أن ==> SCONJ
# حجم ==> NOUN
# فرص ==> NOUN
# الشركات ==> NOUN
# المحلية ==> ADJ
# فى ==> ADP
# عراق ==> NOUN
# ما ==> DET
# بعد ==> ADP
# الحرب ==> NOUN
# يبلغ ==> VERB
# 15 ==> NUM
# مليار ==> NUM
# دولار ==> NOUN
# امريكى ==> ADJ
# . ==> PUNCT
# وحتى ==> None
# و ==> CCONJ
# حتى ==> ADV
# اذا ==> CCONJ
# فازت ==> VERB
# نيودلهي ==> X
# بجانب ==> None
# ب ==> ADP
# جانب ==> NOUN
# من ==> ADP
# هذه ==> DET
# الفرص ==> NOUN
# فحسب ==> None
# ف ==> CCONJ
# حسب ==> NOUN
# ، ==> PUNCT
# فإن ==> None
# ف ==> CCONJ
# إن ==> PART
# اقتصاد ==> NOUN
# الهند ==> NOUN
# سيشهد ==> None
# س ==> AUX
# يشهد ==> VERB
# انتعاشا ==> NOUN
# من ==> ADP
# جديد ==> ADJ
# . ==> PUNCT
# واعترفت ==> None
# و ==> CCONJ
# اعترفت ==> VERB
# الشركات ==> NOUN
# الهندية ==> ADJ
# بأن ==> None
# ب ==> ADP
# أن ==> SCONJ
# الشركات ==> NOUN
# الامريكية ==> ADJ
# العالمية ==> ADJ
# سوف ==> AUX
# تستحوذ ==> VERB
# على ==> ADP
# اكبر ==> X
# العقود ==> NOUN
# نظرا ==> NOUN
# لطبيعة ==> None
# ل ==> ADP
# طبيعة ==> NOUN
# المجهود ==> X
# الحربى ==> X
# ، ==> PUNCT
# لكنها ==> None
# لٰكن ==> CCONJ
# ها ==> PRON
# تأمل ==> VERB
# فى ==> ADP
# تخصيص ==> NOUN
# عدد ==> NOUN
# من ==> ADP
# العقود ==> NOUN
# للشركات ==> None
# ل ==> ADP
# الشركات ==> NOUN
# الهندية ==> ADJ
# . ==> PUNCT
# وكانت ==> None
# و ==> CCONJ
# كانت ==> VERB
# الشركات ==> NOUN
# الهندية ==> NOUN
# العاملة ==> ADJ
# فى ==> ADP
# مجال ==> NOUN
# الانشاءات ==> X
# المدنية ==> ADJ
# فى ==> ADP
# صدارة ==> NOUN
# الانشطة ==> X
# الهندية ==> X
# فى ==> ADP
# العراق ==> NOUN
# ومنطقة ==> None
# و ==> CCONJ
# منطقة ==> NOUN
# الخليج ==> NOUN
# . ==> PUNCT
# ويسود ==> None
# و ==> CCONJ
# يسود ==> VERB
# شعور ==> NOUN
# بان ==> None
# ب ==> ADP
# أن ==> SCONJ
# هذه ==> DET
# الخبرة ==> NOUN
# ستضع ==> None
# س ==> AUX
# تضع ==> VERB
# الشركات ==> NOUN
# الهندية ==> ADJ
# فى ==> ADP
# موضع ==> NOUN
# جيد ==> ADJ
# فى ==> ADP
# عملية ==> NOUN
# اعادة ==> NOUN
# اعمار ==> X
# العراق ==> NOUN
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# اديتيا ==> X
# ميشرا ==> X
# المدير ==> NOUN
# التنفيذى ==> ADJ
# لشركة ==> None
# ل ==> ADP
# شركة ==> NOUN
# راجرانى ==> X
# للتصدير ==> None
# ل ==> ADP
# التصدير ==> NOUN
# المحدودة ==> ADJ
# انه ==> None
# إن ==> SCONJ
# ه ==> PRON
# " ==> PUNCT
# حتى ==> ADV
# لو ==> CCONJ
# حصلوا ==> VERB
# على ==> ADP
# العقود ==> NOUN
# الكبيرة ==> ADJ
# فان ==> None
# ف ==> CCONJ
# إن ==> PART
# عقود ==> NOUN
# اعادة ==> NOUN
# الاعمار ==> X
# المدنى ==> ADJ
# هى ==> PRON
# مجال ==> NOUN
# دخول ==> NOUN
# الهند ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# الا ==> PART
# ان ==> SCONJ
# اعادة ==> NOUN
# الاعمار ==> NOUN
# المدنى ==> ADJ
# ليست ==> VERB
# مجال ==> NOUN
# الاهتمام ==> NOUN
# الوحيد ==> NOUN
# للشركات ==> None
# ل ==> ADP
# الشركات ==> NOUN
# الهندية ==> ADJ
# فى ==> ADP
# عراق ==> NOUN
# ما ==> DET
# بعد ==> ADP
# الحرب ==> NOUN
# . ==> PUNCT
# فقد ==> None
# ف ==> CCONJ
# قد ==> AUX
# اعتبر ==> VERB
# مكتب ==> NOUN
# برنامج ==> NOUN
# العراق ==> NOUN
# فى ==> ADP
# الامم ==> NOUN
# المتحدة ==> ADJ
# مجال ==> NOUN
# الغذاء ==> NOUN
# والصحة ==> None
# و ==> CCONJ
# الصحة ==> NOUN
# والمياه ==> None
# و ==> CCONJ
# المياه ==> NOUN
# والصرف ==> None
# و ==> CCONJ
# الصرف ==> NOUN
# الصحي ==> ADJ
# والتعليم ==> None
# و ==> CCONJ
# التعليم ==> NOUN
# والكهرباء ==> None
# و ==> CCONJ
# الكهرباء ==> NOUN
# والزراعة ==> None
# و ==> CCONJ
# الزراعة ==> NOUN
# مجالات ==> NOUN
# اولوية ==> NOUN
# لبرنامج ==> None
# ل ==> ADP
# برنامج ==> NOUN
# النفط ==> NOUN
# مقابل ==> ADP
# الغذاء ==> NOUN
# . ==> PUNCT
# ويمكن ==> None
# و ==> CCONJ
# يمكن ==> VERB
# للهند ==> None
# ل ==> ADP
# الهند ==> NOUN
# الاسهام ==> NOUN
# بشكل ==> None
# ب ==> ADP
# شكل ==> NOUN
# كبير ==> ADJ
# فى ==> ADP
# جميع ==> NOUN
# هذه ==> DET
# المجالات ==> NOUN
# والاستحواذ ==> None
# و ==> CCONJ
# الاستحواذ ==> NOUN
# على ==> ADP
# طلبات ==> NOUN
# هامة ==> ADJ
# تجعل ==> VERB
# وضع ==> NOUN
# البلاد ==> NOUN
# مريحا ==> ADJ
# بشكل ==> None
# ب ==> ADP
# شكل ==> NOUN
# أكبر ==> ADJ
# . ==> PUNCT
# / ==> PUNCT
# يتبع ==> VERB
# / ==> PUNCT
# تقرير ==> NOUN
# اخبارى ==> ADJ
# : ==> PUNCT
# الشركات ==> NOUN
# الهندية ==> ADJ
# تتطلع ==> VERB
# للفوز ==> None
# ل ==> ADP
# الفوز ==> NOUN
# بعقود ==> None
# ب ==> ADP
# عقود ==> NOUN
# لاعادة ==> None
# ل ==> ADP
# إعادة ==> NOUN
# اعمار ==> X
# العراق ==> NOUN
# / ==> PUNCT
# اضافة ==> NOUN
# اولى ==> ADJ
# واخيرة ==> None
# و ==> CCONJ
# أخيرة ==> ADJ
# / ==> PUNCT
# تقرير ==> NOUN
# اخبارى ==> ADJ
# : ==> PUNCT
# الشركات ==> NOUN
# الهندية ==> NOUN
# تتطلع ==> VERB
# للفوز ==> None
# ل ==> ADP
# الفوز ==> NOUN
# بعقود ==> None
# ب ==> ADP
# عقود ==> NOUN
# لاعادة ==> None
# ل ==> ADP
# إعادة ==> NOUN
# اعمار ==> X
# العراق ==> NOUN
# / ==> PUNCT
# اضافة ==> NOUN
# اولى ==> ADJ
# واخيرة ==> None
# و ==> CCONJ
# أخيرة ==> ADJ
# / ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# اميت ==> X
# ميترا ==> X
# الامين ==> X
# العام ==> ADJ
# لاتحاد ==> None
# ل ==> ADP
# اتحاد ==> NOUN
# غرف ==> X
# الصناعة ==> NOUN
# والتجارة ==> None
# و ==> CCONJ
# التجارة ==> NOUN
# الهندية ==> X
# " ==> PUNCT
# لقد ==> X
# شهد ==> VERB
# هذا ==> DET
# البرنامج ==> NOUN
# بالفعل ==> None
# ب ==> ADP
# الفعل ==> NOUN
# عقودا ==> NOUN
# تصل ==> VERB
# قيمتها ==> None
# قيمة ==> NOUN
# ها ==> PRON
# الى ==> ADP
# 30 ==> NUM
# مليار ==> NUM
# روبية ==> NOUN
# / ==> PUNCT
# 632 ==> NUM
# مليون ==> NUM
# دولار ==> NOUN
# امريكى ==> ADJ
# / ==> PUNCT
# حصلت ==> VERB
# عليها ==> None
# علي ==> ADP
# ها ==> PRON
# الشركات ==> NOUN
# الهندية ==> ADJ
# . ==> PUNCT
# وتشير ==> None
# و ==> CCONJ
# تشير ==> VERB
# تقديرات ==> NOUN
# الاتحاد ==> NOUN
# إلى ==> ADP
# أن ==> SCONJ
# اجمالى ==> NOUN
# تكاليف ==> X
# أعمال ==> NOUN
# اعادة ==> NOUN
# الاعمار ==> NOUN
# ستصل ==> None
# س ==> AUX
# تصل ==> VERB
# إلى ==> ADP
# حوالى ==> ADP
# 300 ==> NUM
# مليار ==> NUM
# دولار ==> NOUN
# منها ==> None
# من ==> ADP
# ها ==> PRON
# 150 ==> NUM
# مليارا ==> NUM
# فى ==> ADP
# شكل ==> NOUN
# عقود ==> NOUN
# من ==> ADP
# الباطن ==> ADJ
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# الاتحاد ==> NOUN
# ان ==> SCONJ
# الشركات ==> NOUN
# الهندية ==> ADJ
# ستحصل ==> None
# س ==> AUX
# تحصل ==> VERB
# على ==> ADP
# عقود ==> NOUN
# من ==> ADP
# الباطن ==> ADJ
# قيمتها ==> None
# قيمة ==> NOUN
# ها ==> PRON
# 15 ==> NUM
# مليار ==> NUM
# دولار ==> NOUN
# فى ==> ADP
# انشطة ==> NOUN
# اعادة ==> NOUN
# الاعمار ==> X
# بالعراق ==> None
# ب ==> ADP
# العراق ==> NOUN
# . ==> PUNCT
# وأضاف ==> None
# و ==> CCONJ
# ...
# . ==> PUNCT
# وأشار ==> None
# و ==> CCONJ
# أشار ==> VERB
# إلى ==> ADP
# أن ==> SCONJ
# جميع ==> NOUN
# مرضى ==> NOUN
# سارس ==> X
# فى ==> ADP
# 13 ==> NUM
# مقاطعة ==> NOUN
# منها ==> None
# من ==> ADP
# ها ==> PRON
# لياونينج ==> X
# وانخوى ==> X
# وشهجيانج ==> X
# أصيبوا ==> VERB
# بعدوى ==> None
# ب ==> ADP
# عدوى ==> NOUN
# المرض ==> NOUN
# خارج ==> ADP
# المناطق ==> NOUN
# التى ==> DET
# يقيمون ==> VERB
# فيها ==> None
# في ==> ADP
# ها ==> PRON
# . ==> PUNCT
# ماليزيا ==> X
# تفرج ==> VERB
# عن ==> ADP
# 22 ==> NUM
# فلبينيا ==> NOUN
# مانيلا ==> X
# 11 ==> NUM
# مايو ==> NOUN
# ذكرت ==> VERB
# وكالة ==> NOUN
# الانباء ==> NOUN
# الفلبينية ==> ADJ
# ان ==> SCONJ
# ماليزيا ==> X
# افرجت ==> VERB
# اليوم ==> NOUN
# عن ==> ADP
# 22 ==> NUM
# فلبينيا ==> NOUN
# كانوا ==> VERB
# قد ==> AUX
# اعتقلوا ==> VERB
# داخل ==> ADP
# المياه ==> NOUN
# الاقليمية ==> ADJ
# الماليزية ==> ADJ
# وبحوزتهم ==> None
# و ==> CCONJ
# ب ==> ADP
# حوزة ==> NOUN
# هم ==> PRON
# متفجرات ==> NOUN
# فى ==> ADP
# الشهر ==> None
# الشهر ==> NOUN
# الماضي ==> ADJ
# . ==> PUNCT
# ونقلت ==> None
# و ==> CCONJ
# نقلت ==> VERB
# الوكالة ==> NOUN
# عن ==> ADP
# بيان ==> NOUN
# لوزارة ==> None
# ل ==> ADP
# وزارة ==> NOUN
# الشؤون ==> NOUN
# الخارجية ==> ADJ
# قوله ==> None
# قول ==> NOUN
# ه ==> PRON
# انه ==> None
# أن ==> SCONJ
# ه ==> PRON
# جرى ==> VERB
# تسليم ==> NOUN
# الفلبينيين ==> NOUN
# الى ==> ADP
# فريق ==> NOUN
# يعمل ==> VERB
# بالقنصلية ==> None
# ب ==> ADP
# القنصلية ==> NOUN
# الفلبينية ==> ADJ
# وانه ==> None
# و ==> CCONJ
# أن ==> SCONJ
# ه ==> PRON
# تم ==> VERB
# نقلهم ==> None
# نقل ==> NOUN
# هم ==> PRON
# بعد ==> ADP
# ذلك ==> DET
# الى ==> ADP
# مدينة ==> NOUN
# سانداكان ==> X
# في ==> ADP
# ولاية ==> NOUN
# سابا ==> X
# الشرقية ==> ADJ
# لركوب ==> X
# عبارة ==> NOUN
# لنقلهم ==> None
# ل ==> ADP
# نقل ==> NOUN
# هم ==> PRON
# الى ==> ADP
# مدينة ==> NOUN
# زامبوانجا ==> X
# فى ==> ADP
# جنوبي ==> X
# الفلبين ==> X
# . ==> PUNCT
# وفى ==> None
# و ==> CCONJ
# في ==> ADP
# البيان ==> NOUN
# اعرب ==> VERB
# بلاس ==> X
# اوبل ==> X
# سكرتير ==> NOUN
# الخارجية ==> NOUN
# الفلبينية ==> ADJ
# عن ==> ADP
# " ==> PUNCT
# التقدير ==> NOUN
# العميق ==> ADJ
# لحكومتنا ==> None
# ل ==> ADP
# حكومة ==> NOUN
# نا ==> PRON
# للاجراء ==> None
# ل ==> ADP
# الإجراء ==> NOUN
# الفورى ==> ADJ
# والمعاملة ==> None
# و ==> CCONJ
# المعاملة ==> NOUN
# العادلة ==> ADJ
# من ==> ADP
# جانب ==> NOUN
# الحكومة ==> NOUN
# الماليزية ==> ADJ
# " ==> PUNCT
# . ==> PUNCT
# وذكر ==> None
# و ==> CCONJ
# ذكر ==> VERB
# البيان ==> NOUN
# ان ==> SCONJ
# الاثنين ==> NUM
# والعشرين ==> None
# و ==> CCONJ
# العشرين ==> NUM
# فلبينيا ==> NOUN
# قد ==> AUX
# اعتقلوا ==> VERB
# فى ==> ADP
# 27 ==> NUM
# ابريل ==> NOUN
# عندما ==> CCONJ
# ضل ==> VERB
# قاربهم ==> None
# قارب ==> NOUN
# هم ==> PRON
# طريقه ==> None
# طريق ==> NOUN
# ه ==> PRON
# فى ==> None
# في ==> ADP
# المياه ==> NOUN
# الماليزية ==> ADJ
# بسبب ==> None
# ب ==> ADP
# سبب ==> NOUN
# سوء ==> NOUN
# حالة ==> NOUN
# الملاحة ==> NOUN
# الليلية ==> ADJ
# . ==> PUNCT
# وقد ==> None
# و ==> CCONJ
# قد ==> AUX
# عثر ==> VERB
# على ==> ADP
# هؤلاء ==> DET
# وبحوزتهم ==> None
# و ==> CCONJ
# ب ==> ADP
# حوزة ==> NOUN
# هم ==> PRON
# متفجرات ==> NOUN
# وذخيرة ==> None
# و ==> CCONJ
# ذخيرة ==> NOUN
# وهو ==> None
# و ==> CCONJ
# هو ==> PRON
# الامر ==> NOUN
# الذى ==> DET
# اثار ==> VERB
# المخاوف ==> NOUN
# من ==> ADP
# احتمال ==> NOUN
# ان ==> SCONJ
# يكونوا ==> VERB
# اعضاء ==> NOUN
# فى ==> ADP
# شبكة ==> NOUN
# الجماعة ==> NOUN
# الاسلامية ==> ADJ
# الارهابية ==> ADJ
# او ==> CCONJ
# جماعات ==> NOUN
# متمردة ==> ADJ
# اسلامية ==> ADJ
# فى ==> ADP
# الفلبين ==> NOUN
# . ==> PUNCT
# وذكرت ==> None
# و ==> CCONJ
# ذكرت ==> VERB
# السلطات ==> NOUN
# الفلبينية ==> ADJ
# فيما ==> None
# في ==> ADP
# ما ==> DET
# بعد ==> ADP
# ان ==> SCONJ
# المعتقلين ==> NOUN
# الفلبينيين ==> ADJ
# كانوا ==> VERB
# فى ==> ADP
# طريقهم ==> None
# طريق ==> NOUN
# هم ==> PRON
# الى ==> ADP
# حفل ==> NOUN
# زفاف ==> NOUN
# فى ==> ADP
# جزيرة ==> NOUN
# جنوبية ==> ADJ
# بالقلبين ==> None
# ب ==> ADP
# القلبين ==> NOUN
# بالقرب ==> None
# ب ==> ADP
# القرب ==> NOUN
# من ==> ADP
# الحدود ==> NOUN
# البحرية ==> ADJ
# بيد ==> CCONJ
# انهم ==> None
# أن ==> SCONJ
# هم ==> PRON
# ضلوا ==> VERB
# طريقهم ==> None
# طريق ==> NOUN
# هم ==> PRON
# داخل ==> ADP
# المياه ==> NOUN
# الماليزية ==> ADJ
# . ==> PUNCT
# وتردد ==> None
# و ==> CCONJ
# تردد ==> VERB
# انهم ==> None
# أن ==> SCONJ
# هم ==> PRON
# جلبوا ==> VERB
# معهم ==> None
# مع ==> ADP
# هم ==> PRON
# المتفجرات ==> NOUN
# والذخيرة ==> None
# و ==> CCONJ
# الذخيرة ==> NOUN
# لأن ==> CCONJ
# ذلك ==> DET
# جزء ==> NOUN
# من ==> ADP
# العادات ==> NOUN
# المتبعة ==> ADJ
# فى ==> ADP
# قريتهم ==> None
# قرية ==> NOUN
# هم ==> PRON
# حيث ==> CCONJ
# اعتاد ==> VERB
# سكانها ==> None
# سكان ==> NOUN
# ها ==> PRON
# اطلاق ==> NOUN
# النار ==> NOUN
# فى ==> ADP
# الهواء ==> NOUN
# خلال ==> ADP
# هذه ==> DET
# الاحتفالات ==> NOUN
# . ==> PUNCT
# الكويت ==> NOUN
# تقرر ==> VERB
# ارسال ==> X
# ثمانى ==> X
# وحدات ==> NOUN
# لتحلية ==> None
# ل ==> ADP
# تحلية ==> NOUN
# المياه ==> NOUN
# الى ==> ADP
# العراق ==> NOUN
# الكويت ==> NOUN
# 11 ==> NUM
# مايو ==> NOUN
# قرر ==> VERB
# مجلس ==> NOUN
# الوزراءالكويتي ==> X
# اليوم ==> NOUN
# ارسال ==> X
# ثمانى ==> X
# وحدات ==> NOUN
# لتكرير ==> None
# ل ==> ADP
# تكرير ==> NOUN
# وتحلية ==> None
# و ==> CCONJ
# تحلية ==> NOUN
# المياه ==> NOUN
# الى ==> ADP
# العراق ==> NOUN
# لتوفير ==> None
# ل ==> ADP
# توفير ==> NOUN
# المياه ==> NOUN
# الصالحة ==> ADJ
# للشرب ==> None
# ل ==> ADP
# الشرب ==> NOUN
# للشعب ==> None
# ل ==> ADP
# الشعب ==> NOUN
# العراقي ==> ADJ
# في ==> ADP
# مبادرة ==> NOUN
# كويتية ==> ADJ
# للحد ==> None
# ل ==> ADP
# الحد ==> NOUN
# من ==> ADP
# انتشار ==> NOUN
# مرض ==> NOUN
# الكوليرا ==> NOUN
# الذي ==> X
# اكتشف ==> VERB
# هناك ==> ADV
# مؤخرا ==> ADJ
# . ==> PUNCT
# جاء ==> VERB
# ذلك ==> X
# فى ==> ADP
# تصريح ==> NOUN
# خاص ==> ADJ
# ادلى ==> VERB
# به ==> None
# ب ==> ADP
# ه ==> PRON
# وزير ==> NOUN
# الكهرباء ==> NOUN
# والماء ==> None
# و ==> CCONJ
# الماء ==> NOUN
# ووزير ==> None
# و ==> CCONJ
# وزير ==> NOUN
# الشؤون ==> NOUN
# الاجتماعية ==> ADJ
# والعمل ==> None
# و ==> CCONJ
# العمل ==> NOUN
# الكويتى ==> ADJ
# طلال ==> X
# العيار ==> X
# لوكالة ==> None
# ل ==> ADP
# وكالة ==> NOUN
# الانباء ==> NOUN
# الكويتية ==> ADJ
# / ==> PUNCT
# كونا ==> X
# / ==> PUNCT
# فى ==> ADP
# اعقاب ==> X
# الاجتماع ==> NOUN
# الاسبوعي ==> ADJ
# لمجلس ==> None
# ل ==> ADP
# مجلس ==> NOUN
# الوزراء ==> NOUN
# المنعقد ==> X
# هنا ==> ADV
# اليوم ==> NOUN
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# أن ==> SCONJ
# المجلس ==> NOUN
# أقر ==> VERB
# ارسال ==> X
# ثمانى ==> X
# وحدات ==> NOUN
# تعمل ==> VERB
# بطريقة ==> None
# ب ==> ADP
# طريقة ==> NOUN
# " ==> PUNCT
# التناضح ==> X
# العكسي ==> X
# " ==> PUNCT
# لتكرير ==> None
# ل ==> ADP
# تكرير ==> NOUN
# وتحلية ==> None
# و ==> CCONJ
# تحلية ==> NOUN
# المياه ==> NOUN
# لمساعدة ==> None
# ل ==> ADP
# مساعدة ==> NOUN
# الشعب ==> NOUN
# العراقي ==> ADJ
# وتوفير ==> None
# و ==> CCONJ
# توفير ==> NOUN
# المياه ==> NOUN
# الصالحة ==> ADJ
# للشرب ==> None
# ل ==> ADP
# الشرب ==> NOUN
# له ==> None
# ل ==> ADP
# ه ==> PRON
# مشيرا ==> NOUN
# الى ==> ADP
# أن ==> SCONJ
# هذه ==> DET
# الوحدات ==> NOUN
# سترسل ==> None
# س ==> AUX
# ترسل ==> VERB
# خلال ==> ADP
# اليومين ==> NOUN
# المقبلين ==> ADJ
# . ==> PUNCT
# وأكد ==> None
# و ==> CCONJ
# أكد ==> VERB
# العيار ==> X
# أن ==> SCONJ
# الاستمرار ==> NOUN
# في ==> ADP
# تقديم ==> NOUN
# المساعدات ==> NOUN
# من ==> ADP
# الكويت ==> NOUN
# الى ==> ADP
# الشعب ==> NOUN
# العراقي ==> ADJ
# " ==> PUNCT
# ما ==> DET
# هو ==> PRON
# الا ==> PART
# جزء ==> NOUN
# مما ==> None
# من ==> ADP
# ما ==> DET
# يحمله ==> None
# يحمل ==> VERB
# ه ==> PRON
# الشعب ==> NOUN
# الكويتي ==> ADJ
# للشعب ==> None
# ل ==> ADP
# الشعب ==> NOUN
# العراقي ==> ADJ
# من ==> ADP
# محبة ==> X
# ومودة ==> None
# و ==> CCONJ
# مودة ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# وأشار ==> None
# و ==> CCONJ
# أشار ==> VERB
# العيار ==> X
# الى ==> ADP
# استمرار ==> NOUN
# المساعدات ==> NOUN
# وفي ==> None
# و ==> CCONJ
# في ==> ADP
# جميع ==> NOUN
# المجالات ==> NOUN
# الغذائية ==> ADJ
# والدوائية ==> None
# و ==> CCONJ
# الدوائية ==> ADJ
# والصحية ==> None
# و ==> CCONJ
# الصحية ==> ADJ
# وغيرها ==> None
# و ==> CCONJ
# غير ==> NOUN
# ها ==> PRON
# موضحا ==> ADJ
# أن ==> SCONJ
# ما ==> DET
# يتعلق ==> VERB
# بوزارة ==> None
# ب ==> ADP
# وزارة ==> NOUN
# الكهرباء ==> NOUN
# والماء ==> None
# و ==> CCONJ
# الماء ==> NOUN
# فانها ==> None
# ف ==> CCONJ
# إن ==> SCONJ
# ها ==> PRON
# لا ==> PART
# تزال ==> VERB
# تقدم ==> VERB
# المياه ==> NOUN
# العذبة ==> ADJ
# الى ==> ADP
# العراق ==> NOUN
# " ==> PUNCT
# فهناك ==> None
# ف ==> CCONJ
# هناك ==> ADV
# أنبوب ==> NOUN
# يصب ==> VERB
# يوميا ==> ADJ
# في ==> ADP
# العراق ==> NOUN
# بطاقة ==> None
# ب ==> ADP
# طاقة ==> NOUN
# مليون ==> NUM
# ونصف ==> None
# و ==> CCONJ
# نصف ==> NOUN
# المليون ==> NUM
# جالون ==> NOUN
# " ==> PUNCT
# . ==> PUNCT
# وأضاف ==> None
# و ==> CCONJ
# أضاف ==> VERB
# أن ==> SCONJ
# فريقا ==> NOUN
# فنيا ==> ADJ
# كهربائيا ==> NOUN
# سيصل ==> None
# س ==> AUX
# يصل ==> VERB
# الى ==> ADP
# العراق ==> NOUN
# في ==> ADP
# غضون ==> NOUN
# الايام ==> X
# القليلة ==> ADJ
# المقبلة ==> ADJ
# لمتابعة ==> None
# ل ==> ADP
# متابعة ==> NOUN
# ما ==> DET
# يتعلق ==> VERB
# باحتياجات ==> None
# ب ==> ADP
# احتياجات ==> NOUN
# الشعب ==> NOUN
# العراقي ==> NOUN
# في ==> ADP
# مجال ==> NOUN
# الكهرباء ==> NOUN
# . ==> PUNCT
# وكان ==> None
# و ==> CCONJ
# كان ==> VERB
# مجلس ==> NOUN
# الوزراء ==> NOUN
# الكويتى ==> ADJ
# قد ==> AUX
# ناقش ==> VERB
# في ==> ADP
# جلسته ==> None
# جلسة ==> NOUN
# ه ==> PRON
# اليوم ==> NOUN
# ما ==> DET
# يتعلق ==> VERB
# بتطورات ==> None
# ب ==> ADP
# تطورات ==> NOUN
# الاوضاع ==> X
# الانسانية ==> ADJ
# في ==> ADP
# العراق ==> NOUN
# لاسيما ==> ADV
# ما ==> DET
# يتعلق ==> VERB
# بانتشار ==> None
# ب ==> ADP
# انتشار ==> NOUN
# مرض ==> NOUN
# الكوليرا ==> NOUN
# بين ==> ADP
# افراد ==> NOUN
# الشعب ==> NOUN
# العراقي ==> ADJ
# لذا ==> CCONJ
# قرر ==> VERB
# ارسال ==> X
# هذه ==> DET
# الوحدات ==> NOUN
# لتحلية ==> None
# ل ==> ADP
# تحلية ==> NOUN
# المياه ==> NOUN
# لمساعدة ==> None
# ل ==> ADP
# مساعدة ==> NOUN
# الشعب ==> NOUN
# العراقي ==> ADJ
# وتوفير ==> None
# و ==> CCONJ
# توفير ==> NOUN
# المياه ==> NOUN
# الصالحة ==> ADJ
# للشرب ==> None
# ل ==> ADP
# الشرب ==> NOUN
# . ==> PUNCT
# ويذكر ==> None
# و ==> CCONJ
# يذكر ==> VERB
# أن ==> SCONJ
# الكويت ==> X
# كانت ==> VERB
# قد ==> AUX
# أعلنت ==> VERB
# في ==> ADP
# الاسبوع ==> NOUN
# الماضي ==> ADJ
# عن ==> ADP
# تخصيصها ==> None
# تخصيص ==> NOUN
# ها ==> PRON
# لثمانية ==> None
# ل ==> ADP
# ثمانية ==> NUM
# ملايين ==> NUM
# دولار ==> NOUN
# كمبادرة ==> None
# ك ==> ADP
# مبادرة ==> NOUN
# منها ==> None
# من ==> ADP
# ها ==> PRON
# لاعادة ==> None
# ل ==> ADP
# إعادة ==> NOUN
# تأهيل ==> NOUN
# مستشفى ==> X
# البصرة ==> NOUN
# العام ==> ADJ
# . ==> PUNCT
# رئيس ==> NOUN
# هيئة ==> NOUN
# الاركان ==> NOUN
# الامريكية ==> ADJ
# يصل ==> VERB
# الى ==> ADP
# الكويت ==> NOUN
# الكويت ==> NOUN
# 11 ==> NUM
# مايو ==> NOUN
# وصل ==> VERB
# رئيس ==> NOUN
# هيئة ==> NOUN
# الاركان ==> NOUN
# الامريكية ==> ADJ
# الفريق ==> NOUN
# أول ==> X
# ريتشارد ==> X
# مايرز ==> X
# ورئيس ==> None
# و ==> CCONJ
# رئيس ==> NOUN
# الادارة ==> NOUN
# المدنية ==> ADJ
# الجديد ==> ADJ
# في ==> ADP
# العراق ==> NOUN
# الدبلوماسي ==> X
# الامريكي ==> ADJ
# السابق ==> ADJ
# بول ==> X
# بريمر ==> X
# الى ==> ADP
# هنا ==> ADV
# اليوم ==> NOUN
# في ==> ADP
# زيارة ==> NOUN
# للكويت ==> None
# ل ==> ADP
# الكويت ==> NOUN
# تستمر ==> VERB
# يومين ==> NOUN
# . ==> PUNCT
# وذكرت ==> None
# و ==> CCONJ
# ذكرت ==> VERB
# وكالة ==> NOUN
# الانباء ==> NOUN
# الكويتية ==> ADJ
# / ==> PUNCT
# كونا ==> X
# / ==> PUNCT
# ان ==> SCONJ
# زيارة ==> NOUN
# الوفد ==> NOUN
# الامريكي ==> ADJ
# للكويت ==> None
# ل ==> ADP
# الكويت ==> NOUN
# تأتى ==> VERB
# في ==> ADP
# اطار ==> NOUN
# جولة ==> NOUN
# فى ==> ADP
# دول ==> NOUN
# مجلس ==> NOUN
# التعاون ==> NOUN
# الخليجي ==> ADJ
# تهدف ==> VERB
# الى ==> ADP
# بحث ==> NOUN
# السبل ==> NOUN
# الكفيلة ==> ADJ
# باعادة ==> None
# ب ==> ADP
# إعادة ==> NOUN
# اعمار ==> X
# العراق ==> NOUN
# بعد ==> ADP
# سقوط ==> NOUN
# نظام ==> NOUN
# صدام ==> X
# حسين ==> X
# . ==> PUNCT
# ومن ==> None
# و ==> CCONJ
# من ==> ADP
# المقرر ==> ADJ
# ان ==> SCONJ
# يعقد ==> VERB
# مايرز ==> X
# وبريمر ==> X
# اللذان ==> DET
# وصلا ==> VERB
# الى ==> ADP
# الكويت ==> NOUN
# قادمين ==> ADJ
# من ==> ADP
# الدوحة ==> NOUN
# سلسلة ==> NOUN
# لقاءات ==> NOUN
# مع ==> ADP
# عدد ==> NOUN
# من ==> ADP
# المسؤولين ==> ADJ
# الكويتيين ==> ADJ
# اضافة ==> NOUN
# الى ==> ADP
# قيامهما ==> None
# قيام ==> NOUN
# هما ==> PRON
# بتفقد ==> None
# ب ==> ADP
# تفقد ==> NOUN
# القوات ==> NOUN
# الامريكية ==> ADJ
# في ==> ADP
# الكويت ==> NOUN
# . ==> PUNCT
# يذكر ==> VERB
# ان ==> SCONJ
# بريمر ==> X
# كان ==> VERB
# رئيسا ==> NOUN
# سابقا ==> NOUN
# لادارة ==> None
# ل ==> ADP
# إدارة ==> NOUN
# مكافحة ==> NOUN
# الارهاب ==> NOUN
# بوزارة ==> None
# ب ==> ADP
# وزارة ==> NOUN
# الخارجية ==> NOUN
# واعلن ==> None
# و ==> CCONJ
# أعلن ==> VERB
# الرئيس ==> NOUN
# الامريكي ==> ADJ
# جورج ==> X
# بوش ==> X
# تعيينه ==> None
# تعيين ==> NOUN
# ه ==> PRON
# في ==> ADP
# منصبه ==> None
# منصب ==> NOUN
# ه ==> PRON
# في ==> ADP
# السادس ==> ADJ
# من ==> ADP
# الشهر ==> NOUN
# الحالي ==> ADJ
# للاشراف ==> None
# ل ==> ADP
# الإشراف ==> NOUN
# على ==> ADP
# جهود ==> NOUN
# واشنطن ==> X
# لانشاء ==> None
# ل ==> ADP
# إنشاء ==> NOUN
# حكومة ==> NOUN
# ديمقراطية ==> ADJ
# في ==> ADP
# العراق ==> NOUN
# واعادة ==> None
# و ==> CCONJ
# إعادة ==> NOUN
# هيكلة ==> NOUN
# الاقتصاد ==> NOUN
# . ==> PUNCT
# وكان ==> None
# و ==> CCONJ
# كان ==> AUX
# في ==> ADP
# استقبال ==> NOUN
# مايزر ==> X
# وبريمر ==> X
# مسؤول ==> NOUN
# اعادة ==> NOUN
# الاعمار ==> NOUN
# في ==> ADP
# العراق ==> NOUN
# الجنرال ==> NOUN
# الامريكي ==> ADJ
# المتقاعد ==> X
# جاي ==> X
# غارنر ==> X
# ورئيس ==> None
# و ==> CCONJ
# رئيس ==> NOUN
# الاركان ==> X
# العامة ==> ADJ
# للجيش ==> None
# ل ==> ADP
# الجيش ==> NOUN
# الكويتي ==> ADJ
# الفريق ==> X
# الركن ==> X
# طيار ==> X
# فهد ==> X
# أحمد ==> X
# الامير ==> X
# وعدد ==> None
# و ==> CCONJ
# عدد ==> NOUN
# من ==> ADP
# القيادات ==> NOUN
# في ==> ADP
# الجيش ==> NOUN
# الكويتى ==> ADJ
# . ==> PUNCT
# تنسيق ==> NOUN
# المواقف ==> NOUN
# بين ==> ADP
# مصر ==> X
# وفلسطين ==> None
# و ==> CCONJ
# فلسطين ==> NOUN
# قبيل ==> ADP
# زيارة ==> NOUN
# باول ==> X
# لمصر ==> ADP
# لمصر ==> NOUN
# القاهرة ==> NOUN
# 11 ==> NUM
# مايو ==> NOUN
# تلقى ==> VERB
# وزير ==> NOUN
# الخارجية ==> NOUN
# المصرى ==> ADJ
# احمد ==> X
# ماهر ==> X
# هنا ==> X
# مساء ==> X
# اليوم ==> NOUN
# الاحد ==> X
# اتصالا ==> NOUN
# هاتفيا ==> ADJ
# من ==> ADP
# نظيره ==> None
# نظير ==> NOUN
# ه ==> PRON
# الفلسطينى ==> NOUN
# نبيل ==> X
# شعث ==> X
# لتنسيق ==> None
# ل ==> ADP
# تنسيق ==> NOUN
# المواقف ==> NOUN
# بين ==> ADP
# الطرفين ==> NOUN
# بشأن ==> None
# ب ==> ADP
# شأن ==> NOUN
# القضية ==> NOUN
# الفلسطينية ==> NOUN
# وذلك ==> None
# و ==> CCONJ
# ذٰلك ==> DET
# قبيل ==> ADP
# زيارة ==> NOUN
# وزير ==> NOUN
# الخارجية ==> NOUN
# الأمريكى ==> ADJ
# كولين ==> X
# باول ==> X
# لمصر ==> None
# ل ==> ADP
# مصر ==> NOUN
# فى ==> ADP
# اعقاب ==> X
# زيارة ==> NOUN
# إسرائيل ==> X
# والاراضى ==> None
# و ==> CCONJ
# الأراضي ==> NOUN
# الفلسطينية ==> ADJ
# . ==> PUNCT
# وقالت ==> None
# و ==> CCONJ
# قالت ==> VERB
# وكالة ==> NOUN
# انباء ==> NOUN
# الشرق ==> NOUN
# الاوسط ==> ADJ
# المصرية ==> ADJ
# ان ==> SCONJ
# شعث ==> X
# ابلغ ==> VERB
# ماهر ==> X
# نتائج ==> NOUN
# المحادثات ==> NOUN
# التى ==> DET
# أجراها ==> None
# أجرا ==> VERB
# ها ==> PRON
# باول ==> X
# مع ==> ADP
# رئيس ==> NOUN
# الوزراء ==> NOUN
# الفلسطينى ==> NOUN
# محمود ==> X
# عباس ==> X
# / ==> PUNCT
# أبو ==> X
# مازن ==> X
# / ==> PUNCT
# فى ==> ADP
# اريحا ==> X
# فى ==> ADP
# وقت ==> NOUN
# سابق ==> ADJ
# من ==> ADP
# اليوم ==> NOUN
# حيث ==> CCONJ
# اكد ==> VERB
# الجانب ==> NOUN
# الفلسطينى ==> ADJ
# على ==> ADP
# موقفه ==> None
# موقف ==> NOUN
# ه ==> PRON
# الثابت ==> ADJ
# إزاء ==> ADP
# خريطة ==> NOUN
# الطريق ==> NOUN
# ، ==> PUNCT
# الخطة ==> NOUN
# السلمية ==> ADJ
# التى ==> DET
# اعدتها ==> None
# أعدت ==> VERB
# ها ==> PRON
# الولايات ==> NOUN
# المتحدة ==> ADJ
# لاحلال ==> None
# ل ==> ADP
# إحلال ==> NOUN
# السلام ==> NOUN
# فى ==> ADP
# المنطقة ==> NOUN
# واقامة ==> None
# و ==> CCONJ
# إقامة ==> NOUN
# دولة ==> NOUN
# فلسطينية ==> ADJ
# مستقلة ==> ADJ
# عام ==> NOUN
# 2005 ==> NUM
# بجانب ==> None
# ب ==> ADP
# جانب ==> NOUN
# إسرائيل ==> X
# . ==> PUNCT
# واكد ==> None
# و ==> CCONJ
# أكد ==> VERB
# شعث ==> X
# فى ==> ADP
# الاتصال ==> NOUN
# على ==> ADP
# ضرورة ==> NOUN
# قبول ==> NOUN
# الجانب ==> NOUN
# الإسرائيلى ==> ADJ
# الخطة ==> NOUN
# بدون ==> X
# تعديل ==> NOUN
# من ==> ADP
# اجل ==> X
# الاسراع ==> X
# فى ==> ADP
# تنفيذها ==> None
# تنفيذ ==> NOUN
# ها ==> PRON
# على ==> ADP
# الواقع ==> NOUN
# موضحا ==> ADJ
# ان ==> SCONJ
# الجانب ==> NOUN
# الفلسطينى ==> ADJ
# يعلق ==> VERB
# آمالا ==> NOUN
# على ==> ADP
# لقاء ==> NOUN
# الرئيس ==> NOUN
# المصرى ==> ADJ
# حسنى ==> X
# مبارك ==> NOUN
# مع ==> ADP
# باول ==> X
# غدا ==> NOUN
# الاحد ==> NOUN
# . ==> PUNCT
# وطالب ==> None
# و ==> CCONJ
# طالب ==> VERB
# باول ==> X
# اليوم ==> NOUN
# الحكومة ==> NOUN
# الفلسطينية ==> ADJ
# الجديدة ==> ADJ
# بمحاربة ==> None
# ب ==> ADP
# محاربة ==> NOUN
# البنية ==> NOUN
# التحتية ==> ADJ
# للارهاب ==> None
# ل ==> ADP
# الإرهاب ==> NOUN
# ونزع ==> None
# و ==> CCONJ
# نزع ==> NOUN
# أسلحة ==> NOUN
# المنظمات ==> NOUN
# الفلسطينية ==> ADJ
# . ==> PUNCT
# وقال ==> None
# و ==> CCONJ
# قال ==> VERB
# باول ==> X
# خلال ==> ADP
# مؤتمر ==> NOUN
# صحفى ==> ADJ
# مشترك ==> ADJ
# مع ==> ADP
# رئيس ==> NOUN
# الوزراء ==> NOUN
# الفلسطينى ==> ADJ
# أبو ==> X
# مازن ==> X
# عقب ==> ADP
# اجتماعهما ==> None
# اجتماع ==> NOUN
# هما ==> PRON
# فى ==> ADP
# أريحا ==> X
# فى ==> ADP
# الضفة ==> NOUN
# الغربية ==> ADJ
# أن ==> SCONJ
# " ==> PUNCT
# على ==> ADP
# الحكومة ==> NOUN
# الفلسطينية ==> ADJ
# وضع ==> NOUN
# حد ==> NOUN
# للإرهاب ==> None
# ل ==> ADP
# الإرهاب ==> NOUN
# وتفكيك ==> None
# و ==> CCONJ
# تفكيك ==> NOUN
# بنيته ==> None
# بنية ==> NOUN
# ه ==> PRON
# التحتية ==> ADJ
# " ==> PUNCT
# . ==> PUNCT

# %%
# count the unique POS
# Flatten the list of lists into a single list

flat_list = [j for i in pos_tags for j in i]

# Count the occurrences of each variable
variable_counts = Counter(flat_list)

# Print unique variables and their counts
for variable, count in variable_counts.items():
    print(f"POS: {variable}, Count: {count}")
# Out:
# POS: X, Count: 13747
# POS: VERB, Count: 16789
# POS: NOUN, Count: 74546
# POS: ADJ, Count: 23498
# POS: ADP, Count: 33617
# POS: PUNCT, Count: 17511
# POS: NUM, Count: 6010
# POS: None, Count: 30519
# POS: PRON, Count: 8533
# POS: SCONJ, Count: 4368
# POS: CCONJ, Count: 15803
# POS: DET, Count: 4648
# POS: PART, Count: 1709
# POS: ADV, Count: 880
# POS: SYM, Count: 329
# POS: AUX, Count: 1699
# POS: PROPN, Count: 187
# POS: INTJ, Count: 7

# %%
# check the data after the split
print("sample of the train data")
read_sentences(train_sentences,train_pos,False)

print("\nsample of the test data")
read_sentences(test_sentences,test_pos,False)

# print("sample of the validation data ")
# read_sentences(val_sentences,val_pos,False)
# Out:
# sample of the train data
# كشفت الأوراق والمستندات و المستندات أن المستشفى تهرب من طلبات المستشفيات الحكومية من الدم باعتبارها ب اعتبار ها تأخذ الدم مجاناً وكان و كان يتم إبلاغ غرفة الطوارئ بوزارة ب وزارة الصحة بكميات ب كميات دم أقل مما من ما هو مدون بالأوراق ب الأوراق الرسمية لعدم ل عدم الاستعانة بكميات ب كميات الدم في الحوادث وحالات و حالات النزيف الحاد .
#
# ومن و من المتوقع ان يستقبل امير قطر الاربعاء في الفندق الذي يقيم فيه في ه كلا من رئيس المجلس النيابي نبيه بري ورئيس و رئيس الحكومة سليم الحص .
#
# من هنا . .
#
# وتعتزم و تعتزم الهند من جهتها جهة ها شراء حاملة الطائرات الروسية " اميرال غورشكوف " وستشتري و س تشتري طائرات ميغ - 29 الوحيدة التي تتلاءم مع حاملة الطائرات هذه . وقد و قد يشمل العقد شراء 60 طائرة .
#
# السودان يصف تقرير الخارجية الامريكية بانه ب أن ه صدمة للسودانيين للسودانيين
#
# كشف تقرير صادر عن جهاز التمثيل التجاري عن انخفاض حجم التبادل التجاري بين مصر والفليبين و الفليبين خلال الفترة من يناير إلى يونيو الماضيين إلى 3 ملايين دولار مقابل 3.86 مليون دولار خلال نفس الفترة من عام 2002 .
#
# الخرطوم 3 مايو
#
#
# sample of the test data
# وكان و كان مصدر فلسطيني رسمي ذكر امس الاثنين ان وزير الخارجية المصري عمرو موسى عرض على محادثيه الفلسطينيين افكارا من شأنها شأن ها افساح المجال امام اجراء محادثات جديدة مع اسرائيل بعد فشل قمة كامب ديفيد في 25 تموز / يوليو .
#
# في خطوة قد تأتي بنتائج ب نتائج عكسية ، تتجه شركات تأمين عالمية لمساعدة ل مساعدة المصريات بفكرة ب فكرة جديدة تماما . .
#
# وأوضح و أوضح السيد الشريف وكيل اللجنة رفض البرلمانيين المصريين لمشروع ل مشروع الكونجرس الأمريكي لمحاسبة ل محاسبة السعودية .
#
# مبايعة جديدة لحسني ل حسني مبارك
#
# تحذير من التقييم النقدي للثروات ل الثروات الطبيعية بضمانها بضمانها بضمانها
#
# وقال و قال لـ " الحياة " رئيس الجمعية الإفريقية للضعف ل الضعف الجنسي الدكتور خالد لطفي إن أبحاث المؤتمر حذرت بشدة ب شدة من زيادة كبيرة لذلك ل ذٰلك المرض الخطير والمحرج و المحرج في أن الأوضاع التي يعيشها يعيش ها الرجال العرب سياسياً واقتصادياً و اقتصاديا واجتماعياً و اجتماعيا وانتشار و انتشار التدخين والتلوث و التلوث وأمراض و أمراض السكر والقلب و القلب وضغط و ضغط الدم تنذر باستفحال ب استفحال المرض ما لم تتخذ الإجراءات لوقف ل وقف نموه نمو ه .
#
# تنتحل صفة خادمة لتتسلل ل تتسلل للمنازل للمنازل

# %% [markdown]
# ### Modelling

# %%
# Preprocess the data
tokenizer = Tokenizer(oov_token='<UNK>')
tokenizer.fit_on_texts(train_sentences)

# Convert text sequences to integer sequences
train_sequences = tokenizer.texts_to_sequences(train_sentences)
# validation_sequences = tokenizer.texts_to_sequences(val_sentences)
test_sequences = tokenizer.texts_to_sequences(test_sentences)

# %%
# the max sentence length in the test and the train

print("the max sentence length in the train data is :",max([len(i) for i in train_sequences]))
print("the max sentence length in the test data is :",max([len(i) for i in test_sequences]))
# Out:
# the max sentence length in the train data is : 478
# the max sentence length in the test data is : 241

# %%
# Padding sequences to ensure uniform length
# max_len = max(len(seq) for seq in train_sequences + test_sequences)
max_len = 100
train_sequences = pad_sequences(train_sequences, maxlen=max_len, padding='post')
test_sequences = pad_sequences(test_sequences, maxlen=max_len, padding='post')

# # Convert POS tags to one-hot encoding
upos_tags = set(tag for tags in train_pos + test_pos for tag in tags)
upos_tag2idx = {tag: idx for idx, tag in enumerate(upos_tags)}
idx2upos_tag = {idx: tag for tag, idx in upos_tag2idx.items()}

train_upos_tags = [[upos_tag2idx[tag] for tag in tags] for tags in train_pos]
test_upos_tags = [[upos_tag2idx[tag] for tag in tags] for tags in test_pos]

train_upos_tags = pad_sequences(train_upos_tags, maxlen=max_len, padding='post')
test_upos_tags = pad_sequences(test_upos_tags, maxlen=max_len, padding='post')
train_upos_tags = [to_categorical(tag, num_classes=len(upos_tags)) for tag in train_upos_tags]
test_upos_tags = [to_categorical(tag, num_classes=len(upos_tags)) for tag in test_upos_tags]

model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=128, input_length=max_len))
model.add(Bidirectional(LSTM(units=128, return_sequences=True)))
model.add(TimeDistributed(Dense(len(upos_tags), activation='softmax')))

# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# # Print model summary
# print(model.summary())

# %%
# Fit the model to the training data
history = model.fit(train_sequences, np.array(train_upos_tags), batch_size=32, epochs=10, validation_split=0.1)

# Evaluate the model on the test data
loss, accuracy = model.evaluate(test_sequences, np.array(test_upos_tags))
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 137/137 [==============================] - 126s 744ms/step - loss: 1.0069 - accuracy: 0.7057 - val_loss: 0.7132 - val_accuracy: 0.8011
# Epoch 2/10
# 137/137 [==============================] - 71s 516ms/step - loss: 0.3496 - accuracy: 0.9061 - val_loss: 0.1513 - val_accuracy: 0.9615
# Epoch 3/10
# 137/137 [==============================] - 58s 424ms/step - loss: 0.0857 - accuracy: 0.9806 - val_loss: 0.0831 - val_accuracy: 0.9766
# Epoch 4/10
# 137/137 [==============================] - 59s 433ms/step - loss: 0.0408 - accuracy: 0.9898 - val_loss: 0.0722 - val_accuracy: 0.9783
# Epoch 5/10
# 137/137 [==============================] - 58s 426ms/step - loss: 0.0271 - accuracy: 0.9922 - val_loss: 0.0710 - val_accuracy: 0.9786
# Epoch 6/10
# 137/137 [==============================] - 56s 412ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0733 - val_accuracy: 0.9789
# Epoch 7/10
# 137/137 [==============================] - 55s 401ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.0766 - val_accuracy: 0.9786
# Epoch 8/10
# 137/137 [==============================] - 56s 409ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.0798 - val_accuracy: 0.9784
# Epoch 9/10
# 137/137 [==============================] - 56s 406ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0870 - val_accuracy: 0.9786
# Epoch 10/10
# 137/137 [==============================] - 57s 414ms/step - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.0935 - val_accuracy: 0.9784
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0935 - accuracy: 0.9772
# Test Loss: 0.09349430352449417, Test Accuracy: 0.9771851897239685

# %% [markdown]
# #### Evaluation

# %% [markdown]
# **Evaluation metric:**
# Accuracy

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(test_sequences, np.array(test_upos_tags))

# Print the evaluation results
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0935 - accuracy: 0.9772
# Test Loss: 0.09349430352449417
# Test Accuracy: 0.9771851897239685

# %%
# Flatten the predicted and ground truth tags for comparison

predictions = model.predict(test_sequences)

flat_predicted_tags = np.argmax(predictions, axis=-1).flatten()
flat_test_tags = np.argmax(test_upos_tags, axis=-1).flatten()

# Calculate accuracy
correct_predictions = np.sum(flat_predicted_tags == flat_test_tags)
total_predictions = len(flat_predicted_tags)
accuracy = correct_predictions / total_predictions

# Print the accuracy
print(f'Test Accuracy: {accuracy}')
# Out:
# 38/38 [==============================] - 5s 111ms/step
# Test Accuracy: 0.9771851851851852

# %% [markdown]
# ### Enhancement

# %% [markdown]
# ### Change the max_len of the sentence to be 450

# %%
# Padding sequences to ensure uniform length
# max_len = max(len(seq) for seq in train_sequences + test_sequences)
max_len = 450
train_sequences = pad_sequences(train_sequences, maxlen=max_len, padding='post')
test_sequences = pad_sequences(test_sequences, maxlen=max_len, padding='post')

# # Convert POS tags to one-hot encoding
upos_tags = set(tag for tags in train_pos + test_pos for tag in tags)
upos_tag2idx = {tag: idx for idx, tag in enumerate(upos_tags)}
idx2upos_tag = {idx: tag for tag, idx in upos_tag2idx.items()}

train_upos_tags = [[upos_tag2idx[tag] for tag in tags] for tags in train_pos]
test_upos_tags = [[upos_tag2idx[tag] for tag in tags] for tags in test_pos]

train_upos_tags = pad_sequences(train_upos_tags, maxlen=max_len, padding='post')
test_upos_tags = pad_sequences(test_upos_tags, maxlen=max_len, padding='post')
train_upos_tags = [to_categorical(tag, num_classes=len(upos_tags)) for tag in train_upos_tags]
test_upos_tags = [to_categorical(tag, num_classes=len(upos_tags)) for tag in test_upos_tags]

model_2 = Sequential()
model_2.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256, input_length=max_len))
model_2.add(Bidirectional(LSTM(units=256, return_sequences=True)))
model_2.add(TimeDistributed(Dense(len(upos_tags), activation='softmax')))

# Compile the model
model_2.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# # Print model summary
# print(model.summary())

# %%
# Fit the model to the training data
history = model_2.fit(train_sequences, np.array(train_upos_tags), batch_size=32, epochs=5, validation_split=0.1)

# Evaluate the model on the test data
loss, accuracy = model_2.evaluate(test_sequences, np.array(test_upos_tags))
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# 137/137 [==============================] - 623s 5s/step - loss: 0.3070 - accuracy: 0.9240 - val_loss: 0.2304 - val_accuracy: 0.9329
# Epoch 2/5
# 137/137 [==============================] - 618s 5s/step - loss: 0.1661 - accuracy: 0.9560 - val_loss: 0.1391 - val_accuracy: 0.9695
# Epoch 3/5
# 137/137 [==============================] - 613s 4s/step - loss: 0.1007 - accuracy: 0.9801 - val_loss: 0.1131 - val_accuracy: 0.9788
# Epoch 4/5
# 137/137 [==============================] - 606s 4s/step - loss: 0.0784 - accuracy: 0.9854 - val_loss: 0.1055 - val_accuracy: 0.9801
# Epoch 5/5
# 137/137 [==============================] - 606s 4s/step - loss: 0.0697 - accuracy: 0.9867 - val_loss: 0.1042 - val_accuracy: 0.9800
# 38/38 [==============================] - 42s 1s/step - loss: 0.1016 - accuracy: 0.9800
# Test Loss: 0.10156344622373581, Test Accuracy: 0.9800310730934143

# %%
# Flatten the predicted and ground truth tags for comparison

predictions_2 = model_2.predict(test_sequences)
flat_predicted_tags = np.argmax(predictions_2, axis=-1).flatten()
flat_test_tags = np.argmax(test_upos_tags, axis=-1).flatten()

# Ensure the shapes match
assert flat_predicted_tags.shape == flat_test_tags.shape, "Shapes of predicted and ground truth tags must match for comparison"

# Calculate accuracy
correct_predictions = np.sum(flat_predicted_tags == flat_test_tags)
total_predictions = len(flat_predicted_tags)
accuracy = correct_predictions / total_predictions

# Print the accuracy
print(f'Test Accuracy: {accuracy}')
# Out:
# 38/38 [==============================] - 42s 1s/step
# Test Accuracy: 0.9800310928212163

# %%
model_2.save("model_2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the saved model
model_2 = load_model("model_2.h5")

# %% [markdown]
# ## Customized testing

# %%
# define afunction to predict

def predict_POS(text,model=model_2,max_len=450,tokenizer=tokenizer, idx2upos_tag=idx2upos_tag):
    input_sequence = tokenizer.texts_to_sequences([text])
    num_words = len(text.split())
    padded_input_sequence = pad_sequences(input_sequence, maxlen=max_len, padding='post')
    predictions = model.predict(padded_input_sequence)
    predicted_tags = [idx2upos_tag[idx] for idx in np.argmax(predictions, axis=-1)[0][:num_words]]

    # reverse the words order in the lest
    rev_predicted_tags=[ predicted_tags[-(i+1)] for i in range(len(predicted_tags))]

    print("the text and the POS are below\n")
    print(text)
    print(rev_predicted_tags)

# %% [markdown]
# ### Test cases

# %%
# sentence 1
predict_POS("اكل الطفل الطعام بعد أن ذهب الى البيت حيث كان في المدرسة")
# Out:
# 1/1 [==============================] - 0s 354ms/step
# the text and the POS are below
#
# اكل الطفل الطعام بعد أن ذهب الى البيت حيث كان في المدرسة
# ['NOUN', 'ADP', 'VERB', 'CCONJ', 'NOUN', 'ADP', 'VERB', 'SCONJ', 'ADP', 'NOUN', 'NOUN', 'VERB']

# %%
# sentence 2
predict_POS("تتميز مصر بكثير من الثروات المعدنية من فضة و نحاس")
# Out:
# 1/1 [==============================] - 0s 162ms/step
# the text and the POS are below
#
# تتميز مصر بكثير من الثروات المعدنية من فضة و نحاس
# ['NOUN', 'CCONJ', None, 'ADP', 'ADJ', 'NOUN', 'ADP', 'X', 'NOUN', 'VERB']

# %%
# sentence 3
predict_POS("مر الرجل بالشارع")
# Out:
# 1/1 [==============================] - 0s 329ms/step
# the text and the POS are below
#
# مر الرجل بالشارع
# ['NOUN', 'NOUN', 'VERB']

# %% [markdown]
# ### Conclusion and final results

# %% [markdown]
# ### In project POS was carried out in Arabic data
# - using the LSTM (bidirectional layers) give a great advantage to the training
# - An enhancement was implemented by increasing the max_number of words entering the model from to word
#
# ### The outcomes of the 2 models are:
# - The accuracy is extremely high 97% to 98%
# - However the accuracies are high, the model struggles in predicting some words due to mainly the small training dataset
